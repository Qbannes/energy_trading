# %% [markdown]
# # Seaborn Distributionsplots

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
# Seaborn hat verschieden Datenbanken w.z.B. tips-Datenbank (Trinkgeld)

tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tips)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips['total_bill'], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips['total_bill'], kde=True, bins=100)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.pairplot(tips, hue='sex',palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Datensatz erstellen
dataset=np.random.randn(25)

# %%
# Ein weiteren Rugplot erstellen
sns.rugplot(dataset)
# Out:
# <Axes: >

# %%
# Die x-Achse des Plots einstellen
x_min=dataset.min()-2
x_max=dataset.max()+2

# %%
# 100 gleich verteilte Punkte von x_min bis x_max
x_axis=np.linspace(x_min,x_max,100)

# %%
# Die Bandbreite (eng.: bandwith) einstellen. Mehr Info via Suchmaschine

bandwidth=((4*dataset.std()**5)/(3*len(dataset)))**.2

# %%
# Eine leere Liste erstellen
kernel_list=[]

# %%
# Jede Funktion visualisieren
for data_point in dataset:

    # Für jeden Punkt wird ein Kernel erstellt und der Liste hinzugefügt
    kernel=stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)

    # Skalieren für die Darstellung
    kernen=kernel/kernel.max()
    kernel=kernel*.4
    plt.plot(x_axis,kernel,color='grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# Kerndichteschätzung über den Plot legen

#Um den KDE-Plot zu erhalten, können wir diese Funktionen summieren.

# Zeichne die Summe der Basisfunktionen
sum_of_kde=np.sum(kernel_list,axis=0)

# Diagramm zeigen
fig=plt.plot(x_axis,sum_of_kde,color='indianred')

# Das erste Rugplot hinzufügen
sns.rugplot(dataset,c='indianred')

# Die y-tick-Markierungen entfernen
plt.yticks([])

# Titel definieren
plt.suptitle('Summe der Basisfunktionen')
# Out:
# Text(0.5, 0.98, 'Summe der Basisfunktionen')

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(tips['tip'])
sns.rugplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips, estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# Out:
# C:\Users\bedla\AppData\Local\Temp\ipykernel_18672\2944203433.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x='day',y='total_bill', hue='smoker', data=tips,palette='coolwarm')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill', hue='sex', data=tips,palette='coolwarm')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips, jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',hue='sex',data=tips,palette='Set1')

# Legende einstellen
ax=sns.stripplot(x='day',y='total_bill',hue='sex',data=tips,palette='Set1')
ax.legend(loc='best')

# %%
# LÖegende: oder dodge=True, dodge heißt ausweichen

sns.stripplot(x='day',y='total_bill',hue='sex',data=tips,palette='Set1', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',hue='sex',data=tips,dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Kombination/Kombinieren von mehreren Plots

sns.violinplot(x='tip',y='day',hue='sex',data=tips,dodge=True)
sns.swarmplot(x='tip',y='day',hue='sex',data=tips,color='black',size=3,dodge=True)
# Out:
# C:\Users\bedla\AppData\Local\Temp\ipykernel_18672\1974091456.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.swarmplot(x='tip',y='day',hue='sex',data=tips,color='black',size=3,dodge=True)
# <Axes: xlabel='tip', ylabel='day'>

# %%
# Größe ändern: zuerst eine matplotlib-Fläche anlegen mit plt.figure(figsize=( , ))

plt.figure(figsize=(11,7))

sns.violinplot(x='tip',y='day',hue='sex',data=tips,dodge=True)
sns.swarmplot(x='tip',y='day',hue='sex',data=tips,color='black',size=3,dodge=True)
# Out:
# C:\Users\bedla\AppData\Local\Temp\ipykernel_18672\2768583224.py:6: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.swarmplot(x='tip',y='day',hue='sex',data=tips,color='black',size=3,dodge=True)
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='violin')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='swarm')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='strip')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='point')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='box')

# %% [markdown]
# # Matrix / Matrizen

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
sns.load_dataset('tips')
sns.load_dataset('flights')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\bedla\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:1321, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1320 try:
# -> 1321     h.request(req.get_method(), req.selector, req.data, headers,
#    1322               encode_chunked=req.has_header('Transfer-encoding'))
#    1323 except OSError as err: # timeout error
#
# File c:\Users\bedla\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\bedla\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
fluege=pd.read_csv(r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Projekt_Energiehandel_Automatisierung\Udemy - Python Bootcamp\flights.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fluege.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# Korrelationen zwischen Kategorien erkennen

nc=tips.select_dtypes(include='number')
nc.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
nc1=fluege.select_dtypes(include='number')
nc1.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
sns.heatmap(nc.corr(),cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(nc1.corr(),cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
fluege.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %% [markdown]
# # pivotieren

# %%
fluege.pivot_table(values='passengers', index='month',columns='year')
# Out:
# year        1949   1950   1951   1952   1953   1954   1955   1956   1957  \
# month
# April      129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0
# August     148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0
# December   118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0
# February   118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0
# January    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0
# July       148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0
# June       135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0
# March      132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0
# May        121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0
# November   104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0
# October    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0
# September  136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0
#
# ...

# %%
# pivotierte Tabelle in einer Heatmap anzeigen. Zunächst die pivotierte Tabelle einer neuen Variable zuweisen

pv_fluege=fluege.pivot_table(values='passengers', index='month',columns='year')
sns.heatmap(pv_fluege, cmap='magma', linecolor='white', linewidth=1)

# Ausgabe: Es ist zu erkennen, dass im July und August die meisten Flüge geschehen sowie die Anzahl der Passagiere
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(pv_fluege, cmap='magma', linecolor='white', linewidth=1)

# %% [markdown]
# # Regression Plots

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':80})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='smoker',col='smoker')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='smoker',col='smoker',row='time')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',
           col='day',row='sex', aspect=0.6)

# %% [markdown]
# # Grids

# %%
# %matpllotlib inline
import matplotlib.pyplot as plt
iris=pd.read_csv(r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Projekt_Energiehandel_Automatisierung\Udemy - Python Bootcamp\iris.csv')
# Out:
# UsageError: Line magic function `%matpllotlib` not found.

# %%
iris.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
sns.PairGrid(iris)

# %%
# Um die Grids zu füllen mit Daten müssen diese gemappt werden

g=sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g.map_diag(plt.hist)
g.map_upper(plt.scatter) # alle Felder, die über der Diagonale liegen
g.map_lower(sns.kdeplot)
plt.show()

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.FacetGrid(tips,col='time',row='smoker')

# %%
gg=sns.FacetGrid(tips,col='time',row='smoker')
gg.map(plt.hist, 'total_bill')

# %%
ggg=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
ggg.map(plt.hist, 'total_bill')

# %%
ggg=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
ggg.map(plt.scatter, 'total_bill','tip').add_legend()

# %%
gggg=sns.JointGrid(x='total_bill',y='tip',data=tips)
gggg.plot(sns.regplot,sns.histplot)
