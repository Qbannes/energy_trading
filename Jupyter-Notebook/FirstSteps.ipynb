# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\Daten\Grosshandelspreise_20251012_20251023_Viertelstunde.csv', sep=';')

print(df.head())
# Out:
#           Datum von         Datum bis  \
# 0  12.10.2025 00:00  12.10.2025 00:15
# 1  12.10.2025 00:15  12.10.2025 00:30
# 2  12.10.2025 00:30  12.10.2025 00:45
# 3  12.10.2025 00:45  12.10.2025 01:00
# 4  12.10.2025 01:00  12.10.2025 01:15
#
#   Deutschland/Luxemburg [€/MWh] Originalauflösungen  \
# 0                                            108,73
# 1                                            105,82
# 2                                             87,80
# 3                                             82,36
# 4                                            101,10
#
#   ∅ Anrainer DE/LU [€/MWh] Originalauflösungen  \
# 0                                        94,41
# 1                                        89,19
# 2                                        77,59
# 3                                        75,37
# 4                                        86,44
#
#   Belgien [€/MWh] Originalauflösungen Dänemark 1 [€/MWh] Originalauflösungen  \
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df['Datum von'], df['Deutschland/Luxemburg [€/MWh] Originalauflösungen'])
plt.xlabel('Datum und Uhrzeit')
plt.ylabel('Preis in €/MWh')
plt.title('Day-Ahead Strompreise')
plt.show()
