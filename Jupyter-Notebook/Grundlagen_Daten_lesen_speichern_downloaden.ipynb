# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Users\\bedla\\Documents\\Ausbildung_Informatik\\1_Praktikum\\Praktikum_Daten-_und_Prozessanalyse\\energy_trading\\Jupyter-Notebook'

# %%
df=pd.read_csv(r"C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Projekt_Energiehandel_Automatisierung\Udemy - Python Bootcamp\Python_Grundlagen_Uebungen_Loesungen\20-Data_Science\2-Pandas\example.csv")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('gespeichert.csv')

# %% [markdown]
# # EXCEL

# %%
df=pd.read_excel(r"C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Projekt_Energiehandel_Automatisierung\Udemy - Python Bootcamp\Python_Grundlagen_Uebungen_Loesungen\20-Data_Science\2-Pandas\Excel_Sample.xlsx", sheet_name='Sheet1")

# %%
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel("gespeichert.xlsx", sheet_name="Sheet1')

# %% [markdown]
# # HTML Import / Webscraping

# %%
df_html=pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list')

# %%
df_html
# Out:
# [                                            Bank Name                City  \
#  0                        The Santa Anna National Bank          Santa Anna
#  1                                Pulaski Savings Bank             Chicago
#  2                  The First National Bank of Lindsay             Lindsay
#  3               Republic First Bank dba Republic Bank        Philadelphia
#  4                                       Citizens Bank            Sac City
#  5                            Heartland Tri-State Bank             Elkhart
#  6                                 First Republic Bank       San Francisco
#  7                                      Signature Bank            New York
#  8                                 Silicon Valley Bank         Santa Clara
#  9                                   Almena State Bank              Almena
#  10                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
type(df_html)
# Out:
# list

# %%
df_html[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
df_html[0].head(6)
# Out:
#                                Bank Name          City         State   Cert  \
# 0           The Santa Anna National Bank    Santa Anna         Texas   5520
# 1                   Pulaski Savings Bank       Chicago      Illinois  28611
# 2     The First National Bank of Lindsay       Lindsay      Oklahoma   4134
# 3  Republic First Bank dba Republic Bank  Philadelphia  Pennsylvania  27332
# 4                          Citizens Bank      Sac City          Iowa   8758
# 5               Heartland Tri-State Bank       Elkhart        Kansas  25851
#
#                Acquiring Institution      Closing Date  Fund  Sort ascending
# 0          Coleman County State Bank     June 27, 2025                 10549
# 1                    Millennium Bank  January 17, 2025                 10548
# 2             First Bank & Trust Co.  October 18, 2024                 10547
# 3  Fulton Bank, National Association    April 26, 2024                 10546
# ...

# %% [markdown]
# # Einlesen mit SQL Anweisungen

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('sqlite:///:memory:')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# sql in eine DataFame Datenbank speichern

df.to_sql('gespeichert',engine)
# Out:
# 4

# %%
# Daten wieder auslesen aus dem DataFrame als Verbindung (con) engine wählen

sql_df=pd.read_sql('gespeichert', con=engine)

# %%
sql_df
# Out:
#    index  Unnamed: 0   a   b   c   d
# 0      0           0   0   1   2   3
# 1      1           1   4   5   6   7
# 2      2           2   8   9  10  11
# 3      3           3  12  13  14  15

# %% [markdown]
# # JSON Input und Output und DataFrame-Erstellung

# %%
from pandas import DataFrame
import json

# %%
json_obj="""
{   "zoo_animal":"Lion",
    "food":["Meat", "Veggies","Honey"],
    "fur":"Golden",
    "clothes":null,
    "diet":[{"zoo_animal":"Gazelle","food":"grass","fur":"Brown"}]
}
"""

# %%
data=json.loads(json_obj)

# %%
data
# Out:
# {'zoo_animal': 'Lion',
#  'food': ['Meat', 'Veggies', 'Honey'],
#  'fur': 'Golden',
#  'clothes': None,
#  'diet': [{'zoo_animal': 'Gazelle', 'food': 'grass', 'fur': 'Brown'}]}

# %%
type(data)
# Out:
# dict

# %%
type(json_obj)
# Out:
# str

# %%
# data wieder zurückverwandeln in einen String

json.dumps(data)
# Out:
# '{"zoo_animal": "Lion", "food": ["Meat", "Veggies", "Honey"], "fur": "Golden", "clothes": null, "diet": [{"zoo_animal": "Gazelle", "food": "grass", "fur": "Brown"}]}'

# %%
df=DataFrame(data['diet'])

# %%
df
# Out:
#   zoo_animal   food    fur
# 0    Gazelle  grass  Brown
