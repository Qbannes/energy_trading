# %% [markdown]
# # Pandas
# - Sieres
#
#
# Pandas installieren
# - pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
# 4 Inputdatensätze erstellen

labels = ['a','b','c']
liste = [10,20,30]
arr = np.array(liste)
dic = {'a':10,'b':20,'c':30}

# %%
pd.series(data=liste)
