# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import tpqoa
from datetime import datetime, timezone, timedelta
import time
import pickle
import warnings
warnings.filterwarnings('ignore')

# ==================== DATEN VORBEREITEN ====================

def prepare_training_data(data, lookback_periods=[5, 15, 30], min_move_pips=3):
    """
    Erweiterte Feature-Engineering für bessere Vorhersagen

    Args:
        data: DataFrame mit 'price' Spalte
        lookback_periods: Liste von Perioden für Rolling-Features
        min_move_pips: Minimale Bewegung in Pips für sinnvolle Labels
    """
    df = data.copy()

    # Basis: Returns
    df['returns'] = np.log(df['price'] / df['price'].shift(1))

    # === TREND FEATURES ===
    for period in lookback_periods:
        # Rolling Returns (Momentum)
        df[f'momentum_{period}'] = df['returns'].rolling(period).sum()

        # Rolling Volatilität
        df[f'volatility_{period}'] = df['returns'].rolling(period).std()

        # Preis relativ zu SMA (Mean-Reversion Signal)
        df[f'price_vs_sma_{period}'] = (df['price'] - df['price'].rolling(period).mean()) / df['price'].rolling(period).std()

    # === MIKROSTRUKTUR FEATURES ===
    # High-Low Range (Volatilität)
    df['hl_range'] = (df['price'].rolling(10).max() - df['price'].rolling(10).min()) / df['price']



    # === RSI-ÄHNLICHER INDIKATOR ===
    for period in [14]:
        delta = df['returns']
        gain = (delta.where(delta > 0, 0)).rolling(period).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(period).mean()
        rs = gain / (loss + 1e-10)
        df[f'rsi_{period}'] = 100 - (100 / (1 + rs))

    # === ZEIT FEATURES ===
    df['hour'] = df.index.hour
    df['is_eu_session'] = ((df['hour'] >= 7) & (df['hour'] < 16)).astype(int)
    df['is_us_session'] = ((df['hour'] >= 13) & (df['hour'] < 21)).astype(int)

    # === LABEL ENGINEERING ===
    # Zukünftiger Return über nächste X Perioden
    forward_periods = 12  # ~1 Minute bei 5-Sekunden-Daten
    df['forward_return'] = df['price'].shift(-forward_periods) / df['price'] - 1

    # Nur labeln wenn Bewegung > min_move_pips
    min_move = min_move_pips * 0.0001  # EUR/USD: 1 pip = 0.0001

    df['direction'] = 0  # Neutral
    df.loc[df['forward_return'] > min_move, 'direction'] = 1   # Long
    df.loc[df['forward_return'] < -min_move, 'direction'] = -1  # Short

    # Nur Trades wenn Signal stark genug
    df['trade_signal'] = df['direction']

    df.dropna(inplace=True)

    return df


def train_model(data_path, output_model_path, output_params_path):
    """Trainiere verbessertes Modell"""

    # Daten laden
    data = pd.read_csv(data_path, parse_dates=['time'], index_col='time')
    data.rename(columns={'c': 'price'}, inplace=True, errors='ignore')

    # Features erstellen
    df = prepare_training_data(data, lookback_periods=[5, 15, 30], min_move_pips=3)

    # Feature-Spalten identifizieren
    feature_cols = [col for col in df.columns if col not in ['price', 'returns', 'forward_return', 'direction', 'trade_signal']]

    # Nur Daten mit Trade-Signalen (nicht neutral)
    train_df = df[df['direction'] != 0].copy()

    print(f"Training samples: {len(train_df)}")
    print(f"Class distribution:\n{train_df['direction'].value_counts()}")

    # Normalisierung
    means = train_df[feature_cols].mean()
    stds = train_df[feature_cols].std()
    train_df[feature_cols] = (train_df[feature_cols] - means) / (stds + 1e-10)

    # Random Forest statt LogReg (fängt Interaktionen besser ab)
    model = RandomForestClassifier(
        n_estimators=100,
        max_depth=10,
        min_samples_split=100,
        min_samples_leaf=50,
        class_weight='balanced',  # Wichtig bei Ungleichgewicht
        random_state=42,
        n_jobs=-1
    )

    model.fit(train_df[feature_cols], train_df['direction'])

    # Evaluation auf Trainingsdaten
    train_df['pred'] = model.predict(train_df[feature_cols])
    hits = (train_df['direction'] == train_df['pred']).sum()
    hit_ratio = hits / len(train_df)
    print(f"\nTraining Hit Ratio: {hit_ratio:.3f}")

    # Feature Importance
    feature_importance = pd.DataFrame({
        'feature': feature_cols,
        'importance': model.feature_importances_
    }).sort_values('importance', ascending=False)
    print("\nTop 10 Features:")
    print(feature_importance.head(10))

    # Modell und Parameter speichern
    pickle.dump(model, open(output_model_path, 'wb'))
    params = {
        'means': means,
        'stds': stds,
        'feature_cols': feature_cols,
        'lookback_periods': [5, 15, 30],
        'min_move_pips': 3
    }
    pickle.dump(params, open(output_params_path, 'wb'))

    print(f"\nModel saved to: {output_model_path}")
    print(f"Parameters saved to: {output_params_path}")

    return model, params


# =*=*=*=*=*=*=*=*=*=*= TRADING BOT =*=*=*=*=*=*=*=*=*=*=

class ImprovedMLTrader(tpqoa.tpqoa):
    def __init__(self, conf_file, instrument, bar_length, model, params, units, confidence_threshold=0.6):
        super().__init__(conf_file)
        self.instrument = instrument
        self.bar_length = pd.to_timedelta(bar_length)
        self.tick_data = pd.DataFrame()
        self.raw_data = None
        self.data = None
        self.last_bar = None
        self.units = units
        self.position = 0
        self.profits = []

        # ML Komponenten
        self.model = model
        self.means = params['means']
        self.stds = params['stds']
        self.feature_cols = params['feature_cols']
        self.lookback_periods = params['lookback_periods']
        self.confidence_threshold = confidence_threshold  # Nur traden, wenn Modell sicher ist

        print(f"Bot initialized with confidence threshold: {confidence_threshold}")

    def get_most_recent(self, days=5):
        """Hole historische Daten"""
        while True:
            time.sleep(2)
            now = datetime.now(timezone.utc).replace(tzinfo=None, microsecond=0)
            past = now - timedelta(days=days)

            df = self.get_history(
                instrument=self.instrument,
                start=past,
                end=now,
                granularity='S5',
                price='M',
                localize=False
            ).c.dropna().to_frame()

            df.rename(columns={'c': 'price'}, inplace=True)
            df = df.resample(self.bar_length, label='right').last().dropna().iloc[:-1]

            self.raw_data = df.copy()
            self.last_bar = self.raw_data.index[-1]

            if pd.to_datetime(datetime.now(timezone.utc)) - self.last_bar < self.bar_length:
                print(f"Loaded {len(self.raw_data)} historical bars")
                break

    def on_success(self, time, bid, ask):
        print(f'\r\nTicks: {self.ticks}', end='', flush=True)

        recent_tick = pd.to_datetime(time)
        df = pd.DataFrame({self.instrument: (ask + bid) / 2}, index=[recent_tick])
        self.tick_data = pd.concat([self.tick_data, df])

        if recent_tick - self.last_bar > self.bar_length:
            self.resample_and_join()
            self.define_strategy()
            self.execute_trades()

    def resample_and_join(self):
        """Resample Tick-Daten zu Bars"""
        resampled = self.tick_data.resample(self.bar_length, label='right').last().ffill().iloc[:-1]
        resampled.rename(columns={self.instrument: 'price'}, inplace=True)

        # Sicherstellen, dass raw_data auch 'price' heißt
        if 'price' not in self.raw_data.columns:
            self.raw_data.rename(columns={self.instrument: 'price'}, inplace=True)

        self.raw_data = pd.concat([self.raw_data, resampled])
        self.tick_data = self.tick_data.iloc[-1:]
        self.last_bar = self.raw_data.index[-1]

    def define_strategy(self):
        """Feature-Berechnung und Vorhersage"""
        df = self.raw_data.copy()

        # Sicherstellen, dass Spalte 'price' heißt
        if 'price' not in df.columns:
            df.rename(columns={self.instrument: 'price'}, inplace=True)

        # Features berechnen (wie im Training)
        df = prepare_training_data(
            df,
            lookback_periods=self.lookback_periods,
            min_move_pips=3
        )

        if len(df) == 0:
            print("Warning: Not enough data for feature calculation")
            self.data = pd.DataFrame()
            return

        # Normalisierung
        df[self.feature_cols] = (df[self.feature_cols] - self.means) / (self.stds + 1e-10)

        # Vorhersage mit Confidence
        probas = self.model.predict_proba(df[self.feature_cols])
        max_proba = probas.max(axis=1)
        predictions = self.model.predict(df[self.feature_cols])

        # Nur traden, wenn Modell sicher ist
        df['position'] = 0
        confident_mask = max_proba >= self.confidence_threshold
        df.loc[confident_mask, 'position'] = predictions[confident_mask]

        self.data = df.copy()

        # Debug output
        if len(df) > 0:
            last_pred = df['position'].iloc[-1]
            last_conf = max_proba[-1]
            print(f" [Pred: {last_pred}, Conf: {last_conf:.2f}]", end=' ', flush=True)

    def execute_trades(self):
        """Trade-Ausführung basierend auf Position"""
        if len(self.data) == 0:
            return

        target_position = self.data['position'].iloc[-1]

        if target_position == 1 and self.position <= 0:
            # Go Long
            units_to_trade = self.units - self.position * self.units
            order = self.create_order(self.instrument, units_to_trade, suppress=True, ret=True)
            self.report_trade(order, 'GOING LONG')
            self.position = 1

        elif target_position == -1 and self.position >= 0:
            # Go Short
            units_to_trade = -self.units - self.position * self.units
            order = self.create_order(self.instrument, units_to_trade, suppress=True, ret=True)
            self.report_trade(order, 'GOING SHORT')
            self.position = -1

        elif target_position == 0 and self.position != 0:
            # Go Neutral
            order = self.create_order(self.instrument, -self.position * self.units, suppress=True, ret=True)
            self.report_trade(order, 'GOING NEUTRAL')
            self.position = 0

    def report_trade(self, order, going):
        """Trade-Reporting"""
        time = order['time']
        units = order['units']
        price = order['price']
        pl = float(order.get('pl', 0))
        self.profits.append(pl)
        cumpl = sum(self.profits)

        print(f"\n{'='*100}")
        print(f"{time} | {going}")
        print(f"{time} | units={units} | price={price} | P&L={pl:.2f} | Cum P&L={cumpl:.2f}")
        print('='*100 + '\n')

    def safe_stream_data(self, minutes=30, chunk_size=100, max_retries=5):
        """Timeout-sicherer Stream mit MINUTEN-Timer"""

        start_time = time.time()
        end_time = start_time + (minutes * 60)
        total_ticks = 0
        retry_count = 0

        print(f"\n SAFE Stream | {minutes} MINUTEN | Ende: {time.strftime('%H:%M:%S', time.localtime(end_time))}")

        while time.time() < end_time and retry_count < max_retries:
            try:
                print(f"\n*        *Laufzeit**: {int((time.time()-start_time)/60)}/{minutes}min | Ticks: {total_ticks}", end=" ")
                self.stream_data(self.instrument, stop=chunk_size)
                total_ticks += self.ticks
                print(f"+{self.ticks} | Total: {total_ticks}")

                retry_count = 0
                time.sleep(1)

            except Exception as e:
                retry_count += 1
                print(f"{type(e).__name__}: {str(e)[:40]}...")
                wait_time = min(retry_count * 2, 10)
                print(f"{wait_time}s Pause (Versuch {retry_count}/{max_retries})")
                time.sleep(wait_time)

            except KeyboardInterrupt:
                print("\n Manuell gestoppt")
                break

        runtime = int((time.time() - start_time) / 60)
        print(f"\n ENDE nach {runtime}min | {total_ticks} Ticks")
        return total_ticks


# ==================== USAGE EXAMPLE ====================

if __name__ == '__main__':
    #==================== 1. Training (einmalig ausführen) ====================

    model, params = train_model(
        data_path=r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_five_minute.csv',
        output_model_path=r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_trained_model.pkl',
        output_params_path=r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_params.pkl'
    )


    # ==================== 2. Trading ====================

    # model = pickle.load(open(r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_trained_model.pkl', 'rb'))
    # params = pickle.load(open(r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_params.pkl', 'rb'))
    #
    # trader = ImprovedMLTrader(
    #     conf_file=r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\oanda.cfg',
    #     instrument='EUR_USD',
    #     bar_length='5min',  # Längere Bars!
    #     model=model,
    #     params=params,
    #     units=10000,
    #     confidence_threshold=0.52  # Nur traden, wenn Modell >65% sicher und somit den Wert auf 0.65 legen
    # )
    #
    # trader.get_most_recent(days=20)
    # trader.safe_stream_data(minutes=90)
    #
    # # Final position schließen
    # if trader.position != 0:
    #     close_order = trader.create_order(
    #         trader.instrument,
    #         -trader.position * trader.units,
    #         suppress=True,
    #         ret=True
    #     )
    #     trader.report_trade(close_order, 'GOING NEUTRAL')
# Out:
# Training samples: 27144
# Class distribution:
# direction
#  1    13616
# -1    13528
# Name: count, dtype: int64
#
# Training Hit Ratio: 0.685
#
# Top 10 Features:
#             feature  importance
# 7     volatility_30    0.137129
# 11             hour    0.111492
# 6       momentum_30    0.106865
# 4     volatility_15    0.105958
# 9          hl_range    0.093658
# 1      volatility_5    0.072015
# 3       momentum_15    0.070823
# 10           rsi_14    0.070747
# 8   price_vs_sma_30    0.065593
# 0        momentum_5    0.053888
#
# Model saved to: C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_trained_model.pkl
# Parameters saved to: C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_params.pkl

# %% [markdown]
# #    ==================== 2. Trading ====================

# %%
    model = pickle.load(open(r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_trained_model.pkl', 'rb'))
    params = pickle.load(open(r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\20260114_params.pkl', 'rb'))

    trader = ImprovedMLTrader(
        conf_file=r'C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Trading\Data\oanda.cfg',
        instrument='EUR_USD',
        bar_length='5min',  # Längere Bars!
        model=model,
        params=params,
        units=25000000,
        confidence_threshold=0.52  # Nur traden, wenn Modell >65% sicher und somit den Wert auf 0.65 legen
    )

    trader.get_most_recent(days=10)
    trader.safe_stream_data(minutes=80)

    # Finale position schließen
    if trader.position != 0:
        close_order = trader.create_order(
            trader.instrument,
            -trader.position * trader.units,
            suppress=True,
            ret=True
        )
        trader.report_trade(close_order, 'GOING NEUTRAL')
# Out:
# Bot initialized with confidence threshold: 0.52
# Loaded 1918 historical bars
#
#  SAFE Stream | 80 MINUTEN | Ende: 16:10:54
#
# *        *Laufzeit**: 0/80min | Ticks: 0
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 100
#
# *        *Laufzeit**: 1/80min | Ticks: 100
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 200
#
# *        *Laufzeit**: 2/80min | Ticks: 200
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 300
#
# *        *Laufzeit**: 3/80min | Ticks: 300
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75 [Pred: -1, Conf: 0.56]
# ====================================================================================================
# 2026-01-27T13:55:00.469522142Z | GOING SHORT
# 2026-01-27T13:55:00.469522142Z | units=-25000000.0 | price=1.19197 | P&L=0.00 | Cum P&L=0.00
# ====================================================================================================
#
#
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 400
#
# *        *Laufzeit**: 4/80min | Ticks: 400
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 500
#
# *        *Laufzeit**: 5/80min | Ticks: 500
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 600
#
# *        *Laufzeit**: 6/80min | Ticks: 600
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 700
#
# *        *Laufzeit**: 7/80min | Ticks: 700
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 800
#
# *        *Laufzeit**: 8/80min | Ticks: 800
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33 [Pred: -1, Conf: 0.55]
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 900
#
# *        *Laufzeit**: 10/80min | Ticks: 900
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1000
#
# *        *Laufzeit**: 11/80min | Ticks: 1000
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1100
#
# *        *Laufzeit**: 12/80min | Ticks: 1100
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1200
#
# *        *Laufzeit**: 13/80min | Ticks: 1200
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88 [Pred: -1, Conf: 0.52]
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1300
#
# *        *Laufzeit**: 14/80min | Ticks: 1300
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1400
#
# *        *Laufzeit**: 15/80min | Ticks: 1400
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1500
#
# *        *Laufzeit**: 16/80min | Ticks: 1500
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1600
#
# *        *Laufzeit**: 17/80min | Ticks: 1600
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1700
#
# *        *Laufzeit**: 18/80min | Ticks: 1700
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65 [Pred: 0, Conf: 0.50]
# ====================================================================================================
# 2026-01-27T14:10:01.439280693Z | GOING NEUTRAL
# 2026-01-27T14:10:01.439280693Z | units=25000000.0 | price=1.19306 | P&L=-22956.84 | Cum P&L=-22956.84
# ====================================================================================================
#
#
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1800
#
# *        *Laufzeit**: 19/80min | Ticks: 1800
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 1900
#
# *        *Laufzeit**: 20/80min | Ticks: 1900
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2000
#
# *        *Laufzeit**: 21/80min | Ticks: 2000
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2100
#
# *        *Laufzeit**: 22/80min | Ticks: 2100
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2200
#
# *        *Laufzeit**: 23/80min | Ticks: 2200
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83 [Pred: 0, Conf: 0.50]
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2300
#
# *        *Laufzeit**: 24/80min | Ticks: 2300
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2400
#
# *        *Laufzeit**: 25/80min | Ticks: 2400
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2500
#
# *        *Laufzeit**: 26/80min | Ticks: 2500
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2600
#
# *        *Laufzeit**: 28/80min | Ticks: 2600
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56 [Pred: 0, Conf: 0.50]
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2700
#
# *        *Laufzeit**: 29/80min | Ticks: 2700
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2800
#
# *        *Laufzeit**: 30/80min | Ticks: 2800
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 2900
#
# *        *Laufzeit**: 31/80min | Ticks: 2900
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3000
#
# *        *Laufzeit**: 32/80min | Ticks: 3000
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3100
#
# *        *Laufzeit**: 33/80min | Ticks: 3100
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18 [Pred: 0, Conf: 0.52]
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3200
#
# *        *Laufzeit**: 35/80min | Ticks: 3200
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3300
#
# *        *Laufzeit**: 36/80min | Ticks: 3300
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3400
#
# *        *Laufzeit**: 37/80min | Ticks: 3400
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3500
#
# *        *Laufzeit**: 38/80min | Ticks: 3500
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17 [Pred: 0, Conf: 0.52]
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3600
#
# *        *Laufzeit**: 40/80min | Ticks: 3600
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3700
#
# *        *Laufzeit**: 40/80min | Ticks: 3700
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3800
#
# *        *Laufzeit**: 41/80min | Ticks: 3800
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 3900
#
# *        *Laufzeit**: 42/80min | Ticks: 3900
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 4000
#
# *        *Laufzeit**: 43/80min | Ticks: 4000
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 4100
#
# *        *Laufzeit**: 43/80min | Ticks: 4100
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36 [Pred: 0, Conf: 0.50]
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 4200
#
# *        *Laufzeit**: 44/80min | Ticks: 4200
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 4300
#
# *        *Laufzeit**: 45/80min | Ticks: 4300
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 4400
#
# *        *Laufzeit**: 45/80min | Ticks: 4400
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# ...
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 6800
#
# *        *Laufzeit**: 68/80min | Ticks: 6800
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38 [Pred: 0, Conf: 0.50]
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 6900
#
# *        *Laufzeit**: 69/80min | Ticks: 6900
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7000
#
# *        *Laufzeit**: 70/80min | Ticks: 7000
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7100
#
# *        *Laufzeit**: 70/80min | Ticks: 7100
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7200
#
# *        *Laufzeit**: 71/80min | Ticks: 7200
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7300
#
# *        *Laufzeit**: 72/80min | Ticks: 7300
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7400
#
# *        *Laufzeit**: 73/80min | Ticks: 7400
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79 [Pred: 0, Conf: 0.51]
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7500
#
# *        *Laufzeit**: 74/80min | Ticks: 7500
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7600
#
# *        *Laufzeit**: 75/80min | Ticks: 7600
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7700
#
# *        *Laufzeit**: 75/80min | Ticks: 7700
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7800
#
# *        *Laufzeit**: 76/80min | Ticks: 7800
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 7900
#
# *        *Laufzeit**: 77/80min | Ticks: 7900
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 8000
#
# *        *Laufzeit**: 78/80min | Ticks: 8000
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58 [Pred: 1, Conf: 0.52]
# ====================================================================================================
# 2026-01-27T15:10:01.512890689Z | GOING LONG
# 2026-01-27T15:10:01.512890689Z | units=25000000.0 | price=1.19596 | P&L=0.00 | Cum P&L=-22956.84
# ====================================================================================================
#
#
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 8100
#
# *        *Laufzeit**: 79/80min | Ticks: 8100
# Ticks: 1
# Ticks: 2
# Ticks: 3
# Ticks: 4
# Ticks: 5
# Ticks: 6
# Ticks: 7
# Ticks: 8
# Ticks: 9
# Ticks: 10
# Ticks: 11
# Ticks: 12
# Ticks: 13
# Ticks: 14
# Ticks: 15
# Ticks: 16
# Ticks: 17
# Ticks: 18
# Ticks: 19
# Ticks: 20
# Ticks: 21
# Ticks: 22
# Ticks: 23
# Ticks: 24
# Ticks: 25
# Ticks: 26
# Ticks: 27
# Ticks: 28
# Ticks: 29
# Ticks: 30
# Ticks: 31
# Ticks: 32
# Ticks: 33
# Ticks: 34
# Ticks: 35
# Ticks: 36
# Ticks: 37
# Ticks: 38
# Ticks: 39
# Ticks: 40
# Ticks: 41
# Ticks: 42
# Ticks: 43
# Ticks: 44
# Ticks: 45
# Ticks: 46
# Ticks: 47
# Ticks: 48
# Ticks: 49
# Ticks: 50
# Ticks: 51
# Ticks: 52
# Ticks: 53
# Ticks: 54
# Ticks: 55
# Ticks: 56
# Ticks: 57
# Ticks: 58
# Ticks: 59
# Ticks: 60
# Ticks: 61
# Ticks: 62
# Ticks: 63
# Ticks: 64
# Ticks: 65
# Ticks: 66
# Ticks: 67
# Ticks: 68
# Ticks: 69
# Ticks: 70
# Ticks: 71
# Ticks: 72
# Ticks: 73
# Ticks: 74
# Ticks: 75
# Ticks: 76
# Ticks: 77
# Ticks: 78
# Ticks: 79
# Ticks: 80
# Ticks: 81
# Ticks: 82
# Ticks: 83
# Ticks: 84
# Ticks: 85
# Ticks: 86
# Ticks: 87
# Ticks: 88
# Ticks: 89
# Ticks: 90
# Ticks: 91
# Ticks: 92
# Ticks: 93
# Ticks: 94
# Ticks: 95
# Ticks: 96
# Ticks: 97
# Ticks: 98
# Ticks: 99
# Ticks: 100+100 | Total: 8200
#
#  ENDE nach 80min | 8200 Ticks
#
# ====================================================================================================
# 2026-01-27T15:11:35.495247570Z | GOING NEUTRAL
# 2026-01-27T15:11:35.495247570Z | units=-25000000.0 | price=1.19546 | P&L=-10507.58 | Cum P&L=-33464.43
# ====================================================================================================
