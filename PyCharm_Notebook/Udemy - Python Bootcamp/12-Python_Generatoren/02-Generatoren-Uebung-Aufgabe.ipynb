# %% [markdown]
# <a href="https://akademie.datamics.com/kursliste/">![title](bg_datamics_top.png)</a>
#
# <center><em>© Datamics</em></center><br><center><em>Besuche uns für mehr Informationen auf <a href='https://akademie.datamics.com/kursliste/'>www.akademie.datamics.com</a></em>

# %% [markdown]
# # Iteratoren und Generatoren Übung - Aufgabe
#
# ## Aufgabe 1
#
# Erstelle einen Generator, der die Quadratzahlen von Zahlen bis zu einer Zahl *n* erstellt.

# %%
def gen_quadrat(N):
    """ Generator zum quadrieren aller Zahlen bis n. """

    pass

# %%
for x in gen_quadrat(10):
    print(x)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ## Aufgabe 2
#
# Erstelle einen Generator, der *n* zufällige Nummer zwischen einer unteren und oberen Grenze (Eingabeparameter) ausgibt. Nutze die Bibliothek `random`. Zum Beispiel:

# %%
import random

random.randint(1,10)
# Out:
# 9

# %%
def zufallszahlen(ab, bis, n):
    """ Generator zum erzeugen von n Zufallszahlen zwischen ab und bis. """

    pass

# %%
for num in zufallszahlen(1, 10, 12):
    print(num)
# Out:
# 6
# 1
# 10
# 5
# 8
# 2
# 8
# 5
# 4
# 5
# 1
# 4

# %% [markdown]
# ## Aufgabe 3
#
# Verwende die Funktion `iter`, um einen String auszugeben.

# %%
mein_string = 'hallo'

# %% [markdown]
# ## Aufgabe 4
#
# Erkläre, in welchem Anwendungsfall du einen Generator mit `yield` einer normalen Funktion mit `return` vorziehen würdest.
# <br><br><br><br><br>

# %% [markdown]
# ## Extrapunkte!
#
# Kannst du erklären, was `gen_vergleich` im Code unten bewirkt? (Hinweis: wir haben das nie in unseren Lektionen gelernt.
#
# *Hinweis: Du kannst Google/Stack Overflow verwenden - Stichwort Generator Comprehension!*

# %%
meine_liste = [1,2,3,4,5]

gen_vergleich = (element for element in meine_liste if element > 3)

for element in gen_vergleich:
    print(element)
# Out:
# 4
# 5

# %% [markdown]
# ## Super!
