# %% [markdown]
# <a href="https://akademie.datamics.com/kursliste/">![title](bg_datamics_top.png)</a>
#
# <center><em>© Datamics</em></center><br><center><em>Besuche uns für mehr Informationen auf <a href='https://akademie.datamics.com/kursliste/'>www.akademie.datamics.com</a></em>

# %% [markdown]
# # Objekte und Datenstrukturen Übung - Aufgabe
#
# ## Teste dein Wissen
#
# #### Beantworte die folgenden Fragen:

# %% [markdown]
# Überlege dir eine kurze Beschreibung aller folgenden Objekttypen und Datenstrukturen:
#
# Zahlen:
#
# Strings:
#
# Listen:
#
# Tupel:
#
# Dictionaries:

# %% [markdown]
# ## Zahlen
#
# Schreibe eine Gleichung, die Multiplikation, Division, einen Exponenten, Addition und Subtraktion nutzt und 100.25 ergibt.
#
# Hinweis: Es geht nur darum, die grundsätzlichen Funktionen der Arithmetik zu kennen, ihr könnt vom Ergebnis aus starten.

# %% [markdown]
# Beantworte diese 3 Fragen, ohne den Code zu schreiben. Dann schreibe den Code und überprüfe deine Ergebnisse.
#
# Was ist das Ergebnis der folgenden Berechnungen?
#
#     4 * (6 + 5)
#
#     4 * 6 + 5
#
#     4 + 6 * 5

# %% [markdown]
# Welchem <i>Typ</i> entspricht das Ergebnis der Gleichung 3 + 1.5 + 4?

# %% [markdown]
# Was würdest du verwenden, um die Quadratwurzel einer Zahl zu erhalten und was für die Quadratur?

# %%
# Quadratwurzel:

# %%
# Quadrat:

# %% [markdown]
# ## Strings
#
# Wir nehmen den String "Hallo" als Ausgangsposition. Verwende eine Indizierung, die den Buchstaben "a" zurückgibt. Nutze die nächste Zelle:

# %%
mein_string = 'Hallo'
# Gebe "a" mittels Indizierung aus

# %% [markdown]
# Schreibe den String "Hallo" rückwärts mittels Slicing:

# %%
mein_string ='Hallo'
# Invertiere den String mittels Slicing

# %% [markdown]
# Zeige zwei Methoden, um den Buchstaben "o" durch Indizierung zu erhalten:

# %%
mein_string ='Hallo'
# Gib das 'o' aus

# Methode 1:

# %%
# Methode 2:

# %% [markdown]
# ## Listen
#
# Erstelle die Liste [0, 0, 0] auf zwei unterschiedliche Arten.

# %%
# Methode 1:

# %%
# Methode 2:

# %% [markdown]
# Ersetze in dieser verschachtelten Liste "Hallo", um stattdessen "Auf Wiedersehen" zu sagen.

# %%
meine_liste = [1, 2, [3, 4, 'Hallo']]

# %% [markdown]
# Sortiere die folgende Liste:

# %%
meine_liste = [3, 4, 5, 5, 6]

# %% [markdown]
# ## Dictionaries
#
# Gib das "Hallo" aus folgenden Dictionaries aus:

# %%
mein_dict = {'Einfacher_Key': 'Hallo'}
# Das "Hallo" ausgeben

# %%
mein_dict = {'k1': {'k2': 'Hallo'}}
# Das "Hallo" ausgeben

# %%
# Es wird etwas schwieriger
mein_dict = {'k1': [{'key_ebene2': ['das ist tief', ['Hallo']]}]}

# Das "Hallo" ausgeben

# %%
# Das wird jetzt schwer und etwas nervig!
mein_dict = {
    'k1': [1, 2, {'k2': ['etwas kompliziert', {'schwer': [1, 2, ['Hallo']]}]}]}
# Das "Hallo" ausgeben

# %% [markdown]
# Kann man ein Dictionary sortieren? Warum oder warum nicht?
#
# ## Tupel
#
# Was ist der Hauptunterschied zwischen Tupeln und Listen?
#
#
# Wie erstellt man ein Tupel?

# %% [markdown]
# ## Set
#
# Was ist einzigartig an Sets?
#
# Benutze ein Set, um die einzigartigen Werte der folgenden Liste zu finden:

# %%
meine_liste = [1, 2, 2, 33, 4, 4, 11, 22, 3, 3, 2]

# %% [markdown]
# ## Booleans
#
# Für das folgende Quiz hier eine Vorschau für die Vergleichsoperatoren:
# <table class="table table-bordered">
# <tr>
# <th style="width:10%">Operator</th><th style="width:45%">Beschreibung</th><th>Beispiel</th>
# </tr>
# <tr>
# <td>==</td>
# <td>Wenn der Wert zweier Operanten gleich ist, wird die Bedingung True (wahr).</td>
# <td> (a == b) ist nicht True.</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>Wenn der Wert zweier Operanten nicht gleich ist, wird die Bedingung True (wahr).</td>
# <td>(a != b) ist True</td>
# </tr>
# <tr>
# <td>&gt;</td>
# <td>Wenn der Wert des linken Operanten größer als der des rechten ist, dann wird die Bedingung True (wahr).</td>
# <td> (a &gt; b) ist nicht Wahr.</td>
# </tr>
# <tr>
# <td>&lt;</td>
# <td>Wenn der Wert des linken Operanten kleiner als der des rechten ist, dann wird die Bedingung True (wahr).</td>
# <td> (a &lt; b) ist True (wahr).</td>
# </tr>
# <tr>
# <td>&gt;=</td>
# <td>Wenn der Wert des linken Operanten größer als oder gleich dem des rechten ist, dann wird die Bedingung True (wahr).</td>
# <td> (a &gt;= b) ist nicht True (wahr). </td>
# </tr>
# <tr>
# <td>&lt;=</td>
# <td>Wenn der Wert des linken Operanten kleiner als oder gleich dem des rechten ist, dann wird die Bedingung True (wahr).</td>
# <td> (a &lt;= b) ist True (wahr). </td>
# </tr>
# </table>
#
# Was wird der Boolean Wert sein, den folgende Codes erzeugen? Antworte, bevor du die Zellen ausführst!

# %%
# Zuerst beantworten, dann ausführen
2 > 3

# %%
# Zuerst beantworten, dann ausführen
3 <= 2

# %%
# Zuerst beantworten, dann ausführen
3 == 2.0

# %%
# Zuerst beantworten, dann ausführen
3.0 == 3

# %%
# Zuerst beantworten, dann ausführen
4**0.5 != 2

# %% [markdown]
# Letzte Frage: Was ergibt der folgende Codeblock?

# %%
# Zwei verschachtelte Listen
l_eins = [1, 2, [3, 4]]
l_zwei = [1, 2, {'k1': 4}]

# True oder False?
l_eins[2][0] >= l_zwei[2]['k1']

# %% [markdown]
# ## Gut gemacht! Du hast die erste Übung ausgeführt!
