# %% [markdown]
# <a href='https://akademie.datamics.com/kursliste/'>![title](bg_datamics_top.png)</a>
# ___
# <center><em>© Datamics</em></center>
# <center><em>Besuche uns für mehr Informationen auf <a href='https://akademie.datamics.com/kursliste/'>www.akademie.datamics.com</a></em></center>

# %% [markdown]
# # Python Email Übung - Ideen
#
# Da wir Code mit deiner persöhnlichen Emailadresse hier nicht verwenden können, statt dessen hier ein paar Ideen für dich zum ausprobieren deiner neuen Fähigkeiten.

# %% [markdown]
# ## Ideen
#
# * Eine tägliche, automatische Emailerinnerung für Termine
# * Scrape ein paar Statistiken von einer Webseite täglich und maile sie dir zu
# * Schicke Freunden und Familie zufällige, lustige Emails
# * Sei kreativ! Bastele dir mit deinen erlernten Fähigkeiten eine spannende Anwendung :)
#
# ## Klasse!
