# %% [markdown]
# <a href="https://akademie.datamics.com/kursliste/">![title](bg_datamics_top.png)</a>
#
# <center><em>© Datamics</em></center><br><center><em>Besuche uns für mehr Informationen auf <a href='https://akademie.datamics.com/kursliste/'>www.akademie.datamics.com</a></em>

# %% [markdown]
# # Forgeschrittene Python Datenstrukturen Übung - Lösung

# %% [markdown]
# ## Fortgeschrittene Zahlen
# **Problem 1:** Wandle 1024 in Binär- und Hexadezimalformat um.

# %%
# Out:
# 0b10000000000
# 0x400

# %% [markdown]
# **Problem 2:** Runde 5.23222 auf zwei Dezimalstellen.

# %%
# Out:
# 5.23

# %% [markdown]
# ## Fortgeschrittene Strings
#
# **Problem 3:** Überprüfe, ob jedes Zeichen in diesem String klein geschrieben ist.

# %%
string = 'Hallo wie geht es dir Marie, fühlst du dich okay?'
# Out:
# False

# %% [markdown]
# **Problem 4:** Wie häufig taucht der Buchstabe 'w' in folgendem String auf?

# %%
string = 'twywywtwywbwhsjhwuwshshwuwwwjdjdid'
# Out:
# 12

# %% [markdown]
# # Fortgeschrittene Sets
# **Problem 5:** Finde die Elemente in set1, die nicht in set2 enthalten sind.

# %%
set1 = {2, 3, 1, 5, 6, 8}
set2 = {3, 1, 7, 5, 6, 8}
# Out:
# {2}

# %% [markdown]
# **Problem 6:** Finde alle Elemente, die in mindestens einem der Sets enthalten sind.

# %%
# Out:
# {1, 2, 3, 5, 6, 7, 8}

# %% [markdown]
# ## Fortgeschrittene Dictionaries
#
# **Problem 7:** Erstelle mit Dictionaryabstraktion dieses Dictionary: {0:0, 1:1, 2:8, 3:27, 4:64}.

# %%
# Out:
# {0: 0, 1: 1, 2: 8, 3: 27, 4: 64}

# %% [markdown]
# ## Fortgeschrittene Listen
#
# **Problem 8:** Kehre die Liste in der nächsten Zelle um.

# %%
list1 = [1, 2, 3, 4]
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# **Problem 9:** Sortiere die folgende Liste:

# %%
list2 = [3, 4, 2, 5, 1]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## Super!
