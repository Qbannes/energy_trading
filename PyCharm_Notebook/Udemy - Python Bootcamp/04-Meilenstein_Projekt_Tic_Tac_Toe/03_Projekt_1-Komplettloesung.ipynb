# %% [markdown]
# <a href="https://akademie.datamics.com/kursliste/">![title](bg_datamics_top.png)</a>
#
# <center><em>© Datamics</em></center><br><center><em>Besuche uns für mehr Informationen auf <a href='https://akademie.datamics.com/kursliste/'>www.akademie.datamics.com</a></em>

# %% [markdown]
# # Meilenstein-Projekt 1: Schrittweise Komplettlösung
#
# Es folgt der Code für das Video der Komplettlösung. Bitte betrachte zum Verständnis die zugehörigen Videos!

# %% [markdown]
# **Schritt 1:** Schreibe eine Funktion, die das Spielfeld ausgeben kann. Setzt euer Spielfeld als Liste auf, deren Indizes 1-9 mit den Nummern auf dem Zahlenfeld korrespondieren. So erhaltet ihr ein 3 x 3 Feld.

# %%
from IPython.display import clear_output


def spielfeld_anzeigen(spielfeld):
    """ Zeige das aktuelle Spielfeld im Terminal an. """

    clear_output()  # Bedenke: Dies funktioniert nur in Jupyter
    print('   |   |')
    print(' ' + spielfeld[7] + ' | ' + spielfeld[8] + ' | ' + spielfeld[9])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + spielfeld[4] + ' | ' + spielfeld[5] + ' | ' + spielfeld[6])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + spielfeld[1] + ' | ' + spielfeld[2] + ' | ' + spielfeld[3])
    print('   |   |')

# %% [markdown]
# **TEST Schritt 1:** Führe deine Funktion auf einer Testversion deines Spielfeldes aus und passe sie gegebenenfalls an.

# %%
test_spielfeld = ['#', 'X', 'O', 'X', 'O', 'X', 'O', 'X', 'O', 'X']
spielfeld_anzeigen(test_spielfeld)
# Out:
#    |   |
#  X | O | X
#    |   |
# -----------
#    |   |
#  O | X | O
#    |   |
# -----------
#    |   |
#  X | O | X
#    |   |

# %% [markdown]
# **Schritt 2:** Schreibe eine Funktion, welches eine Spielereingabe annimmt, um dem Spieler den Marker 'X' oder 'O' zuzuweisen. Verwende eine *while*-Schleife, um erst beim Erhalt einer validen Eingabe fortzufahren.

# %%
def spieler_eingabe():
    """ Erwartet vom Spieler die Eingabe 'X' oder 'O' und gibt diese zurück. """

    markierung = ''
    
    while not (markierung == 'X' or markierung == 'O'):
        markierung = input('Spieler 1: Willst du X oder O sein?').upper()

    if markierung == 'X':
        return ('X', 'O')
    else:
        return ('O', 'X')

# %% [markdown]
# **Schritt 2:** Schreibe eine Funktion, welches eine Spielereingabe annimmt, um dem Spieler den Marker 'X' oder 'O' zuzuweisen. Verwende eine *while*-Schleife, um erst beim Erhalt einer validen Eingabe fortzufahren.

# %%
spieler_eingabe()
# Out:
# Spieler 1: Willst du X oder O sein?x
# ('X', 'O')

# %% [markdown]
# **Schritt 3**: Schreibe eine Funktion, die der Spielfeld-Liste eine Markierung ('X' oder 'O') und eine gewünschte Position (Nummer 1-9) nimmt, und sie der Liste korrekt zuweist.

# %%
def markierung_setzen(spielfeld, markierung, position):
    """ Setzt die markierung im spielfeld am Index position. """

    spielfeld[position] = markierung

# %% [markdown]
# **TEST Schritt 3:** Führe die Funktion *markierung_setzen* mit Testparametern aus und zeige das modifizierte Spielfeld.

# %%
markierung_setzen(test_spielfeld, '$', 8)
spielfeld_anzeigen(test_spielfeld)
# Out:
#    |   |
#  X | $ | X
#    |   |
# -----------
#    |   |
#  O | X | O
#    |   |
# -----------
#    |   |
#  X | O | X
#    |   |

# %% [markdown]
# **Schritt 4**: Schreibt eine Funktion, die das Spielfeld und eine Markierung ('X' oder 'O') nimmt, und überprüft, ob diese Markierung gewonnen hat.

# %%
def sieg_check(spielfeld, markierung):
    """ Gibt True zurück, wenn markierung im aktuellen spielfeld gewinnt. """

    return ((spielfeld[7] == markierung and spielfeld[8] == markierung and spielfeld[9] == markierung) or  # oben
            # mitte
            (spielfeld[4] == markierung and spielfeld[5] == markierung and spielfeld[6] == markierung) or
            # unten
            (spielfeld[1] == markierung and spielfeld[2] == markierung and spielfeld[3] == markierung) or
            # linke seite runter
            (spielfeld[7] == markierung and spielfeld[4] == markierung and spielfeld[1] == markierung) or
            # mitte runter
            (spielfeld[8] == markierung and spielfeld[5] == markierung and spielfeld[2] == markierung) or
            # rechte seite runter
            (spielfeld[9] == markierung and spielfeld[6] == markierung and spielfeld[3] == markierung) or
            # diagonal
            (spielfeld[7] == markierung and spielfeld[5] == markierung and spielfeld[3] == markierung) or
            (spielfeld[9] == markierung and spielfeld[5] == markierung and spielfeld[1] == markierung))  # diagonal

# %% [markdown]
# **TEST Schritt 4:** Teste die Funktion `sieg_check` auf unserem `test_spielfeld` - das Ergebnis sollte True sein!

# %%
sieg_check(test_spielfeld, 'X')
# Out:
# True

# %% [markdown]
# **Schritt 5**: Schreibe eine Funktion, die das Modul `random` nutzt, um zufällig zu entscheiden, welcher Spieler beginnen darf. Recherchiere dazu `random.randint()`. Gib einen String aus, der anzeigt, welcher Spieler beginnen darf.

# %%
import random


def erster_spieler():
    """ Gibt einen String zurück, der einem zufällig ausgewählten Spieler entspricht. """
    
    if random.randint(0, 1) == 0:
        return 'Spieler 2'
    else:
        return 'Spieler 1'

# %% [markdown]
# **Schritt 6**: Schreibt eine Funktion, die überprüft, ob eine Position frei ist und einen Bool'schen Wert ausgibt.

# %%
def platz_check(spielfeld, position):
    """ Überprüft, ob das Feld am Index position im spielfeld frei ist
    und gibt einen entsprechenden bool'schen Wert zurück. 
    """    
    
    return spielfeld[position] == ' '

# %% [markdown]
# **Schritt 7**: Schreibt eine Funktion, die überprüft, ob das Spielfeld voll ist. Ist dies der Fall, soll True ausgegeben werden.

# %%
def spielfeld_voll(spielfeld):
    """ Gibt True zurück, wenn das spielfeld voll ist, und ansonsten False. """
    
    for i in range(1, 10):
        if platz_check(spielfeld, i):
            return False
        
    return True

# %% [markdown]
# **Schritt 8**: Schreibt eine Funktion, die den Spieler nach seiner nächsten Position (Nummer 1-9) fragt. Dann soll die Funktion aus Schritt 6 genutzt werden, um zu kontrollieren, ob diese noch frei ist. Sofern sie frei ist, soll die Position für spätere Nutzung übergeben werden.

# %%
def spieler_wahl(spielfeld):
    """ Erfragt vom Spieler den nächsten Zug, stellt sicher, 
    dass diese Position noch frei ist und gibt sie zurück.
    """    
    
    position = 0

    while position not in [1, 2, 3, 4, 5, 6, 7, 8, 9] or not platz_check(spielfeld, int(position)):
        position = int(input('Wähle deine nächste Position: (1-9) '))

    return position

# %% [markdown]
# **Schritt 9**: Schreibt eine Funktion, die die Spieler fragt, ob sie erneut spielen wollen. Falls ja soll True zurückgegeben werden.

# %%
def neues_spiel():
    """ Fragt die Spieler, ob sie ein weiteres Spiel wünschen und
    gibt einen entsprechenden bool'schen Wert zurück. 
    """
    
    return input('Wollt ihr erneut spielen? Gebt Ja oder Nein ein: ').lower().startswith('j')

# %% [markdown]
# **Schritt 10**: Jetzt kommt der schwierigste Teil. Verwende `while`-Schleifen und die Funktionen, die du bereits implementiert hast, um das Spiel auszuführen!

# %%
print("Willkommen bei Tic Tac Toe!")

while True:
    
    # Das Spielfeld zurücksetzen
    das_feld = [' '] * 10
    spieler1_markierung, spieler2_markierung = spieler_eingabe()
    zug = erster_spieler()
    print(zug + " darf beginnen.")

    spielen = input('Bist du bereit zum spielen? Gib Ja oder Nein ein.')

    if spielen.lower()[0] == 'j':
        spiel_laeuft = True
    else:
        spiel_laeuft = False

    while spiel_laeuft:
        if zug == "Spieler 1":
            # Zug von Spieler 1

            spielfeld_anzeigen(das_feld)
            position = spieler_wahl(das_feld)
            markierung_setzen(das_feld, spieler1_markierung, position)

            if sieg_check(das_feld, spieler1_markierung):
                spielfeld_anzeigen(das_feld)
                print("Glückwunsch! Du hast gewonnen!")
                spiel_laeuft = False
            else:
                if spielfeld_voll(das_feld):
                    spielfeld_anzeigen(das_feld)
                    print("Dieses Spiel ist ein Unentschieden!")
                    break
                else:
                    zug = "Spieler 2"
        else:
            # Zug von Spieler 2

            spielfeld_anzeigen(das_feld)
            position = spieler_wahl(das_feld)
            markierung_setzen(das_feld, spieler2_markierung, position)

            if sieg_check(das_feld, spieler2_markierung):
                spielfeld_anzeigen(das_feld)
                print("Glückwunsch! Du hast gewonnen!")
                spiel_laeuft = False
            else:
                if spielfeld_voll(das_feld):
                    spielfeld_anzeigen(das_feld)
                    print("Dieses Spiel ist ein Unentschieden!")
                    break
                else:
                    zug = "Spieler 1"

    if not neues_spiel():
        break
# Out:
#    |   |
#  X |   |
#    |   |
# -----------
#    |   |
#  X |   |
#    |   |
# -----------
#    |   |
#  X | O | O
#    |   |
# Glückwunsch! Du hast gewonnen!
# Wollt ihr erneut spielen? Gebt Ja oder Nein ein: n

# %% [markdown]
# ## Sehr gut!
