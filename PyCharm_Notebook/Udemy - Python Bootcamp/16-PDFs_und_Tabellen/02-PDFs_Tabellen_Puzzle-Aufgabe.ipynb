# %% [markdown]
# <a href='https://akademie.datamics.com/kursliste/'>![title](bg_datamics_top.png)</a>
# ___
# <center><em>© Datamics</em></center>
# <center><em>Besuche uns für mehr Informationen auf <a href='https://akademie.datamics.com/kursliste/'>www.akademie.datamics.com</a></em></center>

# %% [markdown]
# # PDFs und Tabellen Puzzle - Aufgabe
#
# Du sollst für dieses Puzzle mit zwei Dateien arbeiten und die folgenden Aufgaben lösen:
#
# * Aufgabe 1: Verwende Python, um den Google Drive Link aus der CSV-Datei im Verzeichnis Uebungsdateien zu extrahieren
# * Aufgabe 2: Öffne das PDF in Uebungsdateien und extrahiere die darin enthaltene Telephonnummer (Beachte: Es gibt verschiedene Telephonnummerformate!)

# %% [markdown]
# ## Aufgabe 1: Extrahiere den Google Drive Link aus der CSV-Datei

# %%
# Das korrekte Ergebnis ist dieses:
# Out:
# 'https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q'

# %% [markdown]
# ## Aufgabe 2: Finde die Telephonnummer im PDF

# %%
# Du solltest diese Nummer erhalten:
# 505 503 4455

# %% [markdown]
# ## Gut gemacht!
