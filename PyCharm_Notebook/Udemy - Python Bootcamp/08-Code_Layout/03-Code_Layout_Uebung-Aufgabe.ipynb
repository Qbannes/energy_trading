# %% [markdown]
# <a href="https://akademie.datamics.com/kursliste/">![title](bg_datamics_top.png)</a>
#
# <center><em>© Datamics</em></center><br><center><em>Besuche uns für mehr Informationen auf <a href='https://akademie.datamics.com/kursliste/'>www.akademie.datamics.com</a></em>

# %% [markdown]
# # Code Layout Übung - Aufgabe

# %% [markdown]
# ## Aufgabe 1: Korrigiere das Layout des folgenden Codes

# %%
def BerechneDasMaximumZweierZahlen(VAR1,VAR2) :
    if VAR1>VAR2:
        return VAR1
    return VAR2
BerechneDasMaximumZweierZahlen(1,2)

# %% [markdown]
# ## Aufgabe 1: Lösung
#
# **Beachte:** Hier sind natürlich viele Lösungen gültig, sofern sie PEP8 entsprechen.

# %%
def maximum(var1, var2):
    """ Funktion zur Berechnung des Maximums der beiden Eingabeparameter. """
    
    if var1 > var2:
        return var1
    
    return var2

maximum(1, 2)
# Out:
# 2

# %% [markdown]
# ## Aufgabe 2: Korrektur mit PyLint
#
# Korrigiere die Datei *uebung.py* mit PyLint. Versuche dabei, eine Punktzahl von mehr als 5.0 zu erreichen.

# %%
! pylint uebung.py -r y

# %% [markdown]
# ## Aufgabe 2: Lösung

# %%
""" Modul zum Test von PyLint
"""

class Auto:
    """ Einfache Klasse. """

    marke="VW"
    preis = 99.99

    def daten_ausgeben(self):
        """ Funktion zur Ausgabe von Daten. """

        print(self.marke)
        print(self.preis) 

mein_auto = Auto()
mein_auto.daten_ausgeben()

# %% [markdown]
# ## Prima!
