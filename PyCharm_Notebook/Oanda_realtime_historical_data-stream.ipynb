# %% [markdown]
# # First Steps with the OANDA API

# %% [markdown]
# ## Connecting to the API / Server

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.get_account_summary()
# Out:
# {'id': '101-011-37633556-002',
#  'alias': 'Konto2',
#  'currency': 'EUR',
#  'balance': '99879.6549',
#  'createdByUserID': 37633556,
#  'createdTime': '2025-11-10T13:42:43.019655832Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '-112.0565',
#  'resettablePL': '-112.0565',
#  'resettablePLTime': '0',
#  'financing': '-8.2886',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.03333333333333',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '99879.6549',
#  'marginUsed': '0.0',
#  'marginAvailable': '99879.6549',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '99879.6549',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '99879.6549',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '196'}

# %%
api.account_type
# Out:
# 'practice'

# %%
api.account_id
# Out:
# '101-011-37633556-002'

# %%
api.get_instruments()
# Out:
# [('AUD/CAD', 'AUD_CAD'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('Bitcoin', 'BTC_USD'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('CAD/SGD', 'CAD_SGD'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('China A50', 'CN50_USD'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Copper', 'XCU_USD'),
#  ('Corn', 'CORN_USD'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('Ether', 'ETH_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('GBP/USD', 'GBP_USD'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('Gold', 'XAU_USD'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('Japan 225', 'JP225_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('Litecoin', 'LTC_USD'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('NZD/USD', 'NZD_USD'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('Silver', 'XAG_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('Sugar', 'SUGAR_USD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('UK 100', 'UK100_GBP'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('US Wall St 30', 'US30_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('USD/CNH', 'USD_CNH'),
#  ('USD/CZK', 'USD_CZK'),
#  ('USD/DKK', 'USD_DKK'),
#  ('USD/HKD', 'USD_HKD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('USD/JPY', 'USD_JPY'),
#  ('USD/MXN', 'USD_MXN'),
#  ('USD/NOK', 'USD_NOK'),
#  ('USD/PLN', 'USD_PLN'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/SGD', 'USD_SGD'),
#  ('USD/THB', 'USD_THB'),
#  ('USD/TRY', 'USD_TRY'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('ZAR/JPY', 'ZAR_JPY')]

# %%
instr = api.get_instruments()

# %%
len(instr)
# Out:
# 127

# %%
instr[8]
# Out:
# ('Bitcoin', 'BTC_USD')

# %% [markdown]
# ## Getting Historical Data (Part 1)

# %%
import pandas as pd
import tpqoa
import warnings
warnings.filterwarnings('ignore')

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
help(api.get_history)
# Out:
# Help on method get_history in module tpqoa.tpqoa:
#
# get_history(instrument, start, end, granularity, price, localize=True) method of tpqoa.tpqoa.tpqoa instance
#     Retrieves historical data for instrument.
#
#     Parameters
#     ==========
#     instrument: string
#         valid instrument name
#     start, end: datetime, str
#         Python datetime or string objects for start and end
#     granularity: string
#         a string like 'S5', 'M1' or 'D'
#     price: string
#         one of 'A' (ask), 'B' (bid) or 'M' (middle)
#
#     Returns
#     =======
#     data: pd.DataFrame
#         pandas DataFrame object with data

# %%
api.get_history(instrument = "EUR_USD", start = "2021-01-09", end = "2024-09-09",
                granularity = "D", price = "B")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2021-01-10 22:00:00  1.22140  1.22224  1.21315  1.21497  104515      True
# 2021-01-11 22:00:00  1.21500  1.22091  1.21363  1.22069   98206      True
# 2021-01-12 22:00:00  1.22059  1.22223  1.21389  1.21571   94061      True
# 2021-01-13 22:00:00  1.21495  1.21779  1.21101  1.21496  104506      True
# 2021-01-14 22:00:00  1.21501  1.21619  1.20714  1.20754   91612      True
# ...                      ...      ...      ...      ...     ...       ...
# 2024-09-02 21:00:00  1.10664  1.10722  1.10256  1.10426  101767      True
# 2024-09-03 21:00:00  1.10420  1.10944  1.10370  1.10823  100247      True
# 2024-09-04 21:00:00  1.10821  1.11190  1.10740  1.11099  101712      True
# 2024-09-05 21:00:00  1.11089  1.11547  1.10649  1.10846  136886      True
# 2024-09-08 21:00:00  1.10798  1.10903  1.10331  1.10343   82539      True
#
# [953 rows x 6 columns]

# %%
df = api.get_history(instrument = "EUR_USD", start = "2021-01-09", end = "2024-09-09",granularity = "D", price = "B")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 953 entries, 2021-01-10 22:00:00 to 2024-09-08 21:00:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   o         953 non-null    float64
#  1   h         953 non-null    float64
#  2   l         953 non-null    float64
#  3   c         953 non-null    float64
#  4   volume    953 non-null    int64
#  5   complete  953 non-null    bool
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 45.6 KB

# %%
api.get_history(instrument = "EUR_USD", start = "2024-09-09", end = "2024-09-09",
                granularity = "D", price = "A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2024-09-08 21:00:00  1.10856  1.10919  1.10347  1.10361   82539      True

# %%
api.get_history(instrument = "EUR_USD", start = "2024-09-09", end = "2024-09-09",
                granularity = "D", price = "B")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2024-09-08 21:00:00  1.10798  1.10903  1.10331  1.10343   82539      True

# %% [markdown]
# ## Getting Historical Data (Part 2)

# %%
api.get_history("EUR_USD", "2021-01-09", "2024-09-09", "H1", "A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2021-01-10 22:00:00  1.22240  1.22324  1.22178  1.22222     163      True
# 2021-01-10 23:00:00  1.22228  1.22231  1.21833  1.21880    2591      True
# 2021-01-11 00:00:00  1.21879  1.21969  1.21821  1.21896    2688      True
# 2021-01-11 01:00:00  1.21896  1.21916  1.21721  1.21786    2988      True
# 2021-01-11 02:00:00  1.21784  1.21810  1.21677  1.21810    2398      True
# ...                      ...      ...      ...      ...     ...       ...
# 2024-09-06 19:00:00  1.10869  1.10904  1.10831  1.10893    3272      True
# 2024-09-06 20:00:00  1.10895  1.10896  1.10855  1.10865    1748      True
# 2024-09-08 21:00:00  1.10856  1.10875  1.10840  1.10858     294      True
# 2024-09-08 22:00:00  1.10841  1.10914  1.10841  1.10878    1338      True
# 2024-09-08 23:00:00  1.10880  1.10917  1.10873  1.10874    2719      True
#
# [22841 rows x 6 columns]

# %%
api.get_history("EUR_USD", "2024-09-03", "2024-09-05", "H12", "A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2024-09-02 21:00:00  1.10739  1.10742  1.10489  1.10493   34664      True
# 2024-09-03 09:00:00  1.10494  1.10705  1.10272  1.10440   67103      True
# 2024-09-03 21:00:00  1.10452  1.10637  1.10407  1.10526   40263      True
# 2024-09-04 09:00:00  1.10527  1.10959  1.10408  1.10840   59984      True
# 2024-09-04 21:00:00  1.10854  1.11012  1.10755  1.10999   34402      True

# %%
api.get_history("EUR_USD", "2024-09-03", "2024-09-05", "M1", "A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2024-09-03 00:00:00  1.10680  1.10681  1.10677  1.10680      51      True
# 2024-09-03 00:01:00  1.10679  1.10684  1.10669  1.10678      90      True
# 2024-09-03 00:02:00  1.10679  1.10679  1.10669  1.10673      78      True
# 2024-09-03 00:03:00  1.10672  1.10672  1.10660  1.10660      60      True
# 2024-09-03 00:04:00  1.10662  1.10674  1.10655  1.10674      41      True
# ...                      ...      ...      ...      ...     ...       ...
# 2024-09-04 23:55:00  1.10819  1.10821  1.10818  1.10819      32      True
# 2024-09-04 23:56:00  1.10819  1.10820  1.10811  1.10813      88      True
# 2024-09-04 23:57:00  1.10814  1.10819  1.10812  1.10819      69      True
# 2024-09-04 23:58:00  1.10819  1.10820  1.10817  1.10818      49      True
# 2024-09-04 23:59:00  1.10818  1.10820  1.10798  1.10810      51      True
#
# [2869 rows x 6 columns]

# %%
api.get_history("EUR_USD", "2024-09-03", "2024-09-04", "S5", "A") # drops a Future Warning -> can be ignored for now
# Out:
#                            o        h        l        c  volume  complete
# time
# 2024-09-03 00:00:00  1.10680  1.10681  1.10680  1.10680      12      True
# 2024-09-03 00:00:10  1.10679  1.10680  1.10679  1.10680       4      True
# 2024-09-03 00:00:15  1.10679  1.10681  1.10679  1.10681       8      True
# 2024-09-03 00:00:20  1.10681  1.10681  1.10680  1.10680       5      True
# 2024-09-03 00:00:25  1.10679  1.10680  1.10679  1.10679       4      True
# ...                      ...      ...      ...      ...     ...       ...
# 2024-09-03 23:59:35  1.10499  1.10500  1.10499  1.10500       2      True
# 2024-09-03 23:59:40  1.10501  1.10501  1.10499  1.10499       5      True
# 2024-09-03 23:59:45  1.10500  1.10500  1.10499  1.10499       4      True
# 2024-09-03 23:59:55  1.10495  1.10495  1.10493  1.10493       5      True
# 2024-09-04 00:00:00  1.10489  1.10489  1.10485  1.10485      15      True
#
# [14656 rows x 6 columns]

# %%
api.get_instruments()
# Out:
# [('AUD/CAD', 'AUD_CAD'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('Bitcoin', 'BTC_USD'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('CAD/SGD', 'CAD_SGD'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('China A50', 'CN50_USD'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Copper', 'XCU_USD'),
#  ('Corn', 'CORN_USD'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('Ether', 'ETH_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('GBP/USD', 'GBP_USD'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('Gold', 'XAU_USD'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('Japan 225', 'JP225_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('Litecoin', 'LTC_USD'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('NZD/USD', 'NZD_USD'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('Silver', 'XAG_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('Sugar', 'SUGAR_USD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('UK 100', 'UK100_GBP'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('US Wall St 30', 'US30_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('USD/CNH', 'USD_CNH'),
#  ('USD/CZK', 'USD_CZK'),
#  ('USD/DKK', 'USD_DKK'),
#  ('USD/HKD', 'USD_HKD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('USD/JPY', 'USD_JPY'),
#  ('USD/MXN', 'USD_MXN'),
#  ('USD/NOK', 'USD_NOK'),
#  ('USD/PLN', 'USD_PLN'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/SGD', 'USD_SGD'),
#  ('USD/THB', 'USD_THB'),
#  ('USD/TRY', 'USD_TRY'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('ZAR/JPY', 'ZAR_JPY')]

# %%
api.get_history("SPX500_USD", "2020-08-03", "2020-08-04", "H1", "A")
# Out:
#                           o       h       l       c  volume  complete
# time
# 2020-08-03 00:00:00  3272.8  3276.1  3267.0  3273.5    2094      True
# 2020-08-03 01:00:00  3273.8  3279.6  3271.5  3277.8    1916      True
# 2020-08-03 02:00:00  3278.1  3278.1  3270.5  3271.8     843      True
# 2020-08-03 03:00:00  3272.3  3273.8  3269.5  3270.3     482      True
# 2020-08-03 04:00:00  3270.6  3271.8  3268.5  3271.8     368      True
# 2020-08-03 05:00:00  3272.0  3275.6  3270.0  3272.4     499      True
# 2020-08-03 06:00:00  3272.0  3272.8  3267.3  3270.0     743      True
# 2020-08-03 07:00:00  3270.3  3272.3  3263.0  3272.0    1717      True
# 2020-08-03 08:00:00  3272.3  3275.9  3264.3  3267.8    1160      True
# 2020-08-03 09:00:00  3267.5  3275.3  3266.0  3275.0    1085      True
# 2020-08-03 10:00:00  3274.5  3288.8  3273.8  3288.0    1078      True
# 2020-08-03 11:00:00  3288.3  3292.0  3286.2  3291.8     697      True
# 2020-08-03 12:00:00  3292.3  3294.1  3290.3  3292.5     596      True
# 2020-08-03 13:00:00  3292.6  3293.3  3284.7  3291.0    1555      True
# 2020-08-03 14:00:00  3290.8  3300.0  3286.5  3289.7    1824      True
# 2020-08-03 15:00:00  3290.0  3301.5  3289.2  3298.2     753      True
# 2020-08-03 16:00:00  3298.5  3299.5  3295.0  3296.5     633      True
# 2020-08-03 17:00:00  3297.0  3300.0  3296.2  3298.5     566      True
# 2020-08-03 18:00:00  3298.8  3303.5  3296.7  3302.2     845      True
# 2020-08-03 19:00:00  3302.5  3303.1  3291.5  3295.2    1796      True
# 2020-08-03 20:00:00  3295.0  3298.6  3291.2  3297.0     643      True
# 2020-08-03 22:00:00  3295.8  3296.6  3293.8  3295.3     478      True
# 2020-08-03 23:00:00  3295.0  3298.4  3294.3  3295.8     409      True

# %% [markdown]
# ## Streaming high-frequency real-time Data

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.stream_data('EUR_USD', stop = 10)
# api.stream_data('EUR_USD')
# Out:
# 2025-11-20T08:23:37.665012747Z 1.15152 1.15161
# 2025-11-20T08:23:40.053018392Z 1.15152 1.15162
# 2025-11-20T08:23:43.951986399Z 1.15156 1.15165
# 2025-11-20T08:23:44.491708357Z 1.15159 1.15167
# 2025-11-20T08:23:45.668654500Z 1.15158 1.15168
# 2025-11-20T08:23:47.209863858Z 1.15158 1.15167
# 2025-11-20T08:23:49.646076755Z 1.15158 1.15167
# 2025-11-20T08:23:49.795236485Z 1.15157 1.15167
# 2025-11-20T08:23:53.339801477Z 1.15158 1.15166
# 2025-11-20T08:23:54.113021598Z 1.15157 1.15167

# %%
api.stop_stream()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 api.stop_stream()
#
# TypeError: 'bool' object is not callable

# %% [markdown]
# ## Creating Orders and Executing Trades

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.create_order(instrument = "EUR_USD", units = 99000, sl_distance= 0.1)
# Out:
#  {'id': '145', 'time': '2025-11-11T14:27:04.678972013Z', 'userID': 37633556, 'accountID': '101-011-37633556-002', 'batchID': '144', 'requestID': '115480408883615073', 'type': 'ORDER_FILL', 'orderID': '144', 'instrument': 'EUR_USD', 'units': '99000.0', 'gainQuoteHomeConversionFactor': '0.857559020513', 'lossQuoteHomeConversionFactor': '0.866177704136', 'price': 1.16032, 'fullVWAP': 1.16032, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 1.16022, 'liquidity': '500000'}, {'price': 1.16021, 'liquidity': '500000'}, {'price': 1.1602, 'liquidity': '2000000'}, {'price': 1.16019, 'liquidity': '2000000'}, {'price': 1.16018, 'liquidity': '5000000'}, {'price': 1.16016, 'liquidity': '10000000'}, {'price': 1.16013, 'liquidity': '10000000'}], 'asks': [{'price': 1.16032, 'liquidity': '401000'}, {'price': 1.16034, 'liquidity': '2500000'}, {'price': 1.16035, 'liquidity': '2000000'}, {'price': 1.16036, 'liquidity': '5000000'}, {'price': 1.16039, 'liquidity': '10000000'}, {'price': 1.16042, 'liquidity': '10000000'}], 'closeoutBid': 1.16013, 'closeoutAsk': 1.16042}, 'reason': 'MARKET_ORDER', 'pl': '0.0', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '99752.2614', 'tradeOpened': {'tradeID': '145', 'units': '99000.0', 'price': 1.16032, 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '4.2662', 'initialMarginRequired': '3300.0'}, 'halfSpreadCost': '4.2662'}

# %%
api.create_order(instrument = "EUR_USD", units = -99000, sl_distance= 0.1)
# Out:
#  {'id': '139', 'time': '2025-11-11T14:23:46.642113888Z', 'userID': 37633556, 'accountID': '101-011-37633556-002', 'batchID': '138', 'requestID': '61437212527255677', 'type': 'ORDER_FILL', 'orderID': '138', 'instrument': 'EUR_USD', 'units': '-99000.0', 'gainQuoteHomeConversionFactor': '0.857821482905', 'lossQuoteHomeConversionFactor': '0.866442804341', 'price': 1.15986, 'fullVWAP': 1.15986, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 1.15986, 'liquidity': '500000'}, {'price': 1.15985, 'liquidity': '500000'}, {'price': 1.15984, 'liquidity': '2000000'}, {'price': 1.15983, 'liquidity': '2000000'}, {'price': 1.15982, 'liquidity': '5000000'}, {'price': 1.1598, 'liquidity': '10000000'}, {'price': 1.15977, 'liquidity': '10000000'}], 'asks': [{'price': 1.15997, 'liquidity': '500000'}, {'price': 1.15999, 'liquidity': '2500000'}, {'price': 1.16, 'liquidity': '2000000'}, {'price': 1.16001, 'liquidity': '5000000'}, {'price': 1.16004, 'liquidity': '10000000'}, {'price': 1.16007, 'liquidity': '10000000'}], 'closeoutBid': 1.15977, 'closeoutAsk': 1.16007}, 'reason': 'MARKET_ORDER', 'pl': '0.0', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '99795.993', 'tradeOpened': {'tradeID': '139', 'units': '-99000.0', 'price': 1.15986, 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '4.6943', 'initialMarginRequired': '3300.0'}, 'halfSpreadCost': '4.6943'}

# %%
api.get_account_summary()
# Out:
# {'id': '101-011-37633556-002',
#  'alias': 'Konto2',
#  'currency': 'EUR',
#  'balance': '99991.4402',
#  'createdByUserID': 37633556,
#  'createdTime': '2025-11-10T13:42:43.019655832Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '-8.5598',
#  'resettablePL': '-8.5598',
#  'resettablePLTime': '0',
#  'financing': '0.0',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.03333333333333',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '99991.4402',
#  'marginUsed': '0.0',
#  'marginAvailable': '99991.4402',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '99991.4402',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '99991.4402',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '59'}

# %%
api.get_transactions(tid = 1) # insert the id of the first trade in this session
# Out:
# [{'id': '2',
#   'time': '2025-11-10T13:42:43.019655832Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '1',
#   'requestID': '1610675111623833662',
#   'type': 'CLIENT_CONFIGURE',
#   'alias': 'Konto2',
#   'marginRate': '0.03333333333333'},
#  {'id': '3',
#   'time': '2025-11-10T13:42:45.246190650Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '3',
#   'requestID': '1592660713121193827',
#   'type': 'TRANSFER_FUNDS',
#   'amount': '100000.0',
#   'fundingReason': 'ADJUSTMENT',
#   'accountBalance': '100000.0'},
#  {'id': '4',
#   'time': '2025-11-10T14:02:32.696028069Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '4',
#   'requestID': '97465641813057020',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '1000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER'},
#  {'id': '5',
#   'time': '2025-11-10T14:02:32.696028069Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '4',
#   'requestID': '97465641813057020',
#   'type': 'ORDER_FILL',
#   'orderID': '4',
#   'instrument': 'EUR_USD',
#   'units': '1000.0',
#   'gainQuoteHomeConversionFactor': '0.860205761874',
#   'lossQuoteHomeConversionFactor': '0.868851045913',
#   'price': 1.15675,
#   'fullVWAP': 1.15675,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15665, 'liquidity': '500000'},
#     {'price': 1.15664, 'liquidity': '500000'},
#     {'price': 1.15663, 'liquidity': '2000000'},
#     {'price': 1.15662, 'liquidity': '2000000'},
#     {'price': 1.15661, 'liquidity': '5000000'},
#     {'price': 1.15659, 'liquidity': '10000000'},
#     {'price': 1.15656, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15675, 'liquidity': '500000'},
#     {'price': 1.15677, 'liquidity': '2500000'},
#     {'price': 1.15678, 'liquidity': '2000000'},
#     {'price': 1.15679, 'liquidity': '5000000'},
#     {'price': 1.15682, 'liquidity': '10000000'},
#     {'price': 1.15685, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15656,
#    'closeoutAsk': 1.15685},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '100000.0',
#   'tradeOpened': {'tradeID': '5',
#    'units': '1000.0',
#    'price': 1.15675,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.0432',
#    'initialMarginRequired': '33.3333'},
#   'halfSpreadCost': '0.0432'},
#  {'id': '6',
#   'time': '2025-11-10T14:03:08.297493074Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '6',
#   'requestID': '97465641964079277',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-1000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'REDUCE_ONLY',
#   'tradeClose': {'tradeID': '5', 'units': '1000'},
#   'reason': 'TRADE_CLOSE'},
#  {'id': '7',
#   'time': '2025-11-10T14:03:08.297493074Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '6',
#   'requestID': '97465641964079277',
#   'type': 'ORDER_FILL',
#   'orderID': '6',
#   'instrument': 'EUR_USD',
#   'units': '-1000.0',
#   'gainQuoteHomeConversionFactor': '0.860321046033',
#   'lossQuoteHomeConversionFactor': '0.868967488707',
#   'price': 1.1565,
#   'fullVWAP': 1.1565,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.1565, 'liquidity': '500000'},
#     {'price': 1.15649, 'liquidity': '500000'},
#     {'price': 1.15648, 'liquidity': '2000000'},
#     {'price': 1.15647, 'liquidity': '2000000'},
#     {'price': 1.15646, 'liquidity': '5000000'},
#     {'price': 1.15644, 'liquidity': '10000000'},
#     {'price': 1.15641, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15659, 'liquidity': '500000'},
#     {'price': 1.15661, 'liquidity': '2500000'},
#     {'price': 1.15662, 'liquidity': '2000000'},
#     {'price': 1.15663, 'liquidity': '5000000'},
#     {'price': 1.15666, 'liquidity': '10000000'},
#     {'price': 1.15669, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15641,
#    'closeoutAsk': 1.15669},
#   'reason': 'MARKET_ORDER_TRADE_CLOSE',
#   'pl': '-0.2172',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99999.7828',
#   'tradesClosed': [{'tradeID': '5',
#     'units': '-1000.0',
#     'price': 1.1565,
#     'realizedPL': '-0.2172',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.0389'}],
#   'halfSpreadCost': '0.0389'},
#  {'id': '8',
#   'time': '2025-11-10T14:04:11.394537747Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '8',
#   'requestID': '61436845210267922',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '10000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER'},
#  {'id': '9',
#   'time': '2025-11-10T14:04:11.394537747Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '8',
#   'requestID': '61436845210267922',
#   'type': 'ORDER_FILL',
#   'orderID': '8',
#   'instrument': 'EUR_USD',
#   'units': '10000.0',
#   'gainQuoteHomeConversionFactor': '0.860306169886',
#   'lossQuoteHomeConversionFactor': '0.868952463051',
#   'price': 1.15662,
#   'fullVWAP': 1.15662,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15651, 'liquidity': '500000'},
#     {'price': 1.1565, 'liquidity': '500000'},
#     {'price': 1.15649, 'liquidity': '2000000'},
#     {'price': 1.15648, 'liquidity': '2000000'},
#     {'price': 1.15647, 'liquidity': '5000000'},
#     {'price': 1.15645, 'liquidity': '10000000'},
#     {'price': 1.15642, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15662, 'liquidity': '500000'},
#     {'price': 1.15664, 'liquidity': '2500000'},
#     {'price': 1.15665, 'liquidity': '2000000'},
#     {'price': 1.15666, 'liquidity': '5000000'},
#     {'price': 1.15669, 'liquidity': '10000000'},
#     {'price': 1.15672, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15642,
#    'closeoutAsk': 1.15672},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99999.7828',
#   'tradeOpened': {'tradeID': '9',
#    'units': '10000.0',
#    'price': 1.15662,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.4755',
#    'initialMarginRequired': '333.3333'},
#   'halfSpreadCost': '0.4755'},
#  {'id': '10',
#   'time': '2025-11-10T14:06:01.147128332Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '10',
#   'requestID': '61436845671737929',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-10000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'REDUCE_ONLY',
#   'tradeClose': {'tradeID': '9', 'units': '10000'},
#   'reason': 'TRADE_CLOSE'},
#  {'id': '11',
#   'time': '2025-11-10T14:06:01.147128332Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '10',
#   'requestID': '61436845671737929',
#   'type': 'ORDER_FILL',
#   'orderID': '10',
#   'instrument': 'EUR_USD',
#   'units': '-10000.0',
#   'gainQuoteHomeConversionFactor': '0.860361962512',
#   'lossQuoteHomeConversionFactor': '0.869008816407',
#   'price': 1.15643,
#   'fullVWAP': 1.15643,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15643, 'liquidity': '500000'},
#     {'price': 1.15642, 'liquidity': '500000'},
#     {'price': 1.15641, 'liquidity': '2000000'},
#     {'price': 1.1564, 'liquidity': '2000000'},
#     {'price': 1.15639, 'liquidity': '5000000'},
#     {'price': 1.15637, 'liquidity': '10000000'},
#     {'price': 1.15634, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15655, 'liquidity': '500000'},
#     {'price': 1.15657, 'liquidity': '2500000'},
#     {'price': 1.15658, 'liquidity': '2000000'},
#     {'price': 1.15659, 'liquidity': '5000000'},
#     {'price': 1.15662, 'liquidity': '10000000'},
#     {'price': 1.15665, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15634,
#    'closeoutAsk': 1.15665},
#   'reason': 'MARKET_ORDER_TRADE_CLOSE',
#   'pl': '-1.6511',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99998.1317',
#   'tradesClosed': [{'tradeID': '9',
#     'units': '-10000.0',
#     'price': 1.15643,
#     'realizedPL': '-1.6511',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.5188'}],
#   'halfSpreadCost': '0.5188'},
#  {'id': '12',
#   'time': '2025-11-10T14:06:10.105248881Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '12',
#   'requestID': '97465642727586639',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '10000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER'},
#  {'id': '13',
#   'time': '2025-11-10T14:06:10.105248881Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '12',
#   'requestID': '97465642727586639',
#   'type': 'ORDER_FILL',
#   'orderID': '12',
#   'instrument': 'EUR_USD',
#   'units': '10000.0',
#   'gainQuoteHomeConversionFactor': '0.860343363791',
#   'lossQuoteHomeConversionFactor': '0.868990030764',
#   'price': 1.15657,
#   'fullVWAP': 1.15657,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15646, 'liquidity': '500000'},
#     {'price': 1.15645, 'liquidity': '500000'},
#     {'price': 1.15644, 'liquidity': '2000000'},
#     {'price': 1.15643, 'liquidity': '2000000'},
#     {'price': 1.15642, 'liquidity': '5000000'},
#     {'price': 1.1564, 'liquidity': '10000000'},
#     {'price': 1.15637, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15657, 'liquidity': '500000'},
#     {'price': 1.15659, 'liquidity': '2500000'},
#     {'price': 1.1566, 'liquidity': '2000000'},
#     {'price': 1.15661, 'liquidity': '5000000'},
#     {'price': 1.15664, 'liquidity': '10000000'},
#     {'price': 1.15667, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15637,
#    'closeoutAsk': 1.15667},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99998.1317',
#   'tradeOpened': {'tradeID': '13',
#    'units': '10000.0',
#    'price': 1.15657,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.4756',
#    'initialMarginRequired': '333.3333'},
#   'halfSpreadCost': '0.4756'},
#  {'id': '14',
#   'time': '2025-11-10T14:09:16.015898652Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '14',
#   'requestID': '115480042016429088',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-10000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'REDUCE_ONLY',
#   'tradeClose': {'tradeID': '13', 'units': '10000'},
#   'reason': 'TRADE_CLOSE'},
#  {'id': '15',
#   'time': '2025-11-10T14:09:16.015898652Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '14',
#   'requestID': '115480042016429088',
#   'type': 'ORDER_FILL',
#   'orderID': '14',
#   'instrument': 'EUR_USD',
#   'units': '-10000.0',
#   'gainQuoteHomeConversionFactor': '0.860283855087',
#   'lossQuoteHomeConversionFactor': '0.868929923982',
#   'price': 1.15654,
#   'fullVWAP': 1.15654,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15654, 'liquidity': '500000'},
#     {'price': 1.15653, 'liquidity': '500000'},
#     {'price': 1.15652, 'liquidity': '2000000'},
#     {'price': 1.15651, 'liquidity': '2000000'},
#     {'price': 1.1565, 'liquidity': '5000000'},
#     {'price': 1.15648, 'liquidity': '10000000'},
#     {'price': 1.15645, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15665, 'liquidity': '500000'},
#     {'price': 1.15667, 'liquidity': '2500000'},
#     {'price': 1.15668, 'liquidity': '2000000'},
#     {'price': 1.15669, 'liquidity': '5000000'},
#     {'price': 1.15672, 'liquidity': '10000000'},
#     {'price': 1.15675, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15645,
#    'closeoutAsk': 1.15675},
#   'reason': 'MARKET_ORDER_TRADE_CLOSE',
#   'pl': '-0.2607',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99997.871',
#   'tradesClosed': [{'tradeID': '13',
#     'units': '-10000.0',
#     'price': 1.15654,
#     'realizedPL': '-0.2607',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.4755'}],
#   'halfSpreadCost': '0.4755'},
#  {'id': '16',
#   'time': '2025-11-10T14:09:28.533870488Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '16',
#   'requestID': '97465643558220054',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '1.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER'},
#  {'id': '17',
#   'time': '2025-11-10T14:09:28.533870488Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '16',
#   'requestID': '97465643558220054',
#   'type': 'ORDER_FILL',
#   'orderID': '16',
#   'instrument': 'EUR_USD',
#   'units': '1.0',
#   'gainQuoteHomeConversionFactor': '0.860265259774',
#   'lossQuoteHomeConversionFactor': '0.868911141782',
#   'price': 1.15667,
#   'fullVWAP': 1.15667,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15657, 'liquidity': '500000'},
#     {'price': 1.15656, 'liquidity': '500000'},
#     {'price': 1.15655, 'liquidity': '2000000'},
#     {'price': 1.15654, 'liquidity': '2000000'},
#     {'price': 1.15653, 'liquidity': '5000000'},
#     {'price': 1.15651, 'liquidity': '10000000'},
#     {'price': 1.15648, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15667, 'liquidity': '500000'},
#     {'price': 1.15669, 'liquidity': '2500000'},
#     {'price': 1.1567, 'liquidity': '2000000'},
#     {'price': 1.15671, 'liquidity': '5000000'},
#     {'price': 1.15674, 'liquidity': '10000000'},
#     {'price': 1.15677, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15648,
#    'closeoutAsk': 1.15677},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99997.871',
#   'tradeOpened': {'tradeID': '17',
#    'units': '1.0',
#    'price': 1.15667,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.0',
#    'initialMarginRequired': '0.0333'},
#   'halfSpreadCost': '0.0'},
#  {'id': '18',
#   'time': '2025-11-10T14:09:35.594193759Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '18',
#   'requestID': '97465643587585990',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-1.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'REDUCE_ONLY',
#   'tradeClose': {'tradeID': '17', 'units': '1'},
#   'reason': 'TRADE_CLOSE'},
#  {'id': '19',
#   'time': '2025-11-10T14:09:35.594193759Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '18',
#   'requestID': '97465643587585990',
#   'type': 'ORDER_FILL',
#   'orderID': '18',
#   'instrument': 'EUR_USD',
#   'units': '-1.0',
#   'gainQuoteHomeConversionFactor': '0.860291292196',
#   'lossQuoteHomeConversionFactor': '0.868937435836',
#   'price': 1.15654,
#   'fullVWAP': 1.15654,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15654, 'liquidity': '500000'},
#     {'price': 1.15653, 'liquidity': '500000'},
#     {'price': 1.15652, 'liquidity': '2000000'},
#     {'price': 1.15651, 'liquidity': '2000000'},
#     {'price': 1.1565, 'liquidity': '5000000'},
#     {'price': 1.15648, 'liquidity': '10000000'},
#     {'price': 1.15645, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15663, 'liquidity': '500000'},
#     {'price': 1.15665, 'liquidity': '2500000'},
#     {'price': 1.15666, 'liquidity': '2000000'},
#     {'price': 1.15667, 'liquidity': '5000000'},
#     {'price': 1.1567, 'liquidity': '10000000'},
#     {'price': 1.15673, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15645,
#    'closeoutAsk': 1.15673},
#   'reason': 'MARKET_ORDER_TRADE_CLOSE',
#   'pl': '-0.0001',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99997.8709',
#   'tradesClosed': [{'tradeID': '17',
#     'units': '-1.0',
#     'price': 1.15654,
#     'realizedPL': '-0.0001',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.0'}],
#   'halfSpreadCost': '0.0'},
#  {'id': '20',
#   'time': '2025-11-10T14:09:41.416303505Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '20',
#   'requestID': '97465643612756398',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '1000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER'},
#  {'id': '21',
#   'time': '2025-11-10T14:09:41.416303505Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '20',
#   'requestID': '97465643612756398',
#   'type': 'ORDER_FILL',
#   'orderID': '20',
#   'instrument': 'EUR_USD',
#   'units': '1000.0',
#   'gainQuoteHomeConversionFactor': '0.860291293225',
#   'lossQuoteHomeConversionFactor': '0.868937436875',
#   'price': 1.15664,
#   'fullVWAP': 1.15664,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15653, 'liquidity': '500000'},
#     {'price': 1.15652, 'liquidity': '500000'},
#     {'price': 1.15651, 'liquidity': '2000000'},
#     {'price': 1.1565, 'liquidity': '2000000'},
#     {'price': 1.15649, 'liquidity': '5000000'},
#     {'price': 1.15647, 'liquidity': '10000000'},
#     {'price': 1.15644, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15664, 'liquidity': '500000'},
#     {'price': 1.15666, 'liquidity': '2500000'},
#     {'price': 1.15667, 'liquidity': '2000000'},
#     {'price': 1.15668, 'liquidity': '5000000'},
#     {'price': 1.15671, 'liquidity': '10000000'},
#     {'price': 1.15674, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15644,
#    'closeoutAsk': 1.15674},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99997.8709',
#   'tradeOpened': {'tradeID': '21',
#    'units': '1000.0',
#    'price': 1.15664,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.0476',
#    'initialMarginRequired': '33.3333'},
#   'halfSpreadCost': '0.0476'},
#  {'id': '22',
#   'time': '2025-11-10T14:10:31.133081801Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '22',
#   'requestID': '79451245313944264',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-1000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'REDUCE_ONLY',
#   'tradeClose': {'tradeID': '21', 'units': '1000'},
#   'reason': 'TRADE_CLOSE'},
#  {'id': '23',
#   'time': '2025-11-10T14:10:31.133081801Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '22',
#   'requestID': '79451245313944264',
#   'type': 'ORDER_FILL',
#   'orderID': '22',
#   'instrument': 'EUR_USD',
#   'units': '-1000.0',
#   'gainQuoteHomeConversionFactor': '0.860135118307',
#   'lossQuoteHomeConversionFactor': '0.868779692361',
#   'price': 1.15675,
#   'fullVWAP': 1.15675,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15675, 'liquidity': '500000'},
#     {'price': 1.15674, 'liquidity': '500000'},
#     {'price': 1.15673, 'liquidity': '2000000'},
#     {'price': 1.15672, 'liquidity': '2000000'},
#     {'price': 1.15671, 'liquidity': '5000000'},
#     {'price': 1.15669, 'liquidity': '10000000'},
#     {'price': 1.15666, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15684, 'liquidity': '500000'},
#     {'price': 1.15686, 'liquidity': '2500000'},
#     {'price': 1.15687, 'liquidity': '2000000'},
#     {'price': 1.15688, 'liquidity': '5000000'},
#     {'price': 1.15691, 'liquidity': '10000000'},
#     {'price': 1.15694, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15666,
#    'closeoutAsk': 1.15694},
#   'reason': 'MARKET_ORDER_TRADE_CLOSE',
#   'pl': '0.0946',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99997.9655',
#   'tradesClosed': [{'tradeID': '21',
#     'units': '-1000.0',
#     'price': 1.15675,
#     'realizedPL': '0.0946',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.0389'}],
#   'halfSpreadCost': '0.0389'},
#  {'id': '24',
#   'time': '2025-11-11T09:26:19.222849902Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '24',
#   'requestID': '79451536175780492',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '25',
#   'time': '2025-11-11T09:26:19.222849902Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '24',
#   'requestID': '79451536175780492',
#   'type': 'ORDER_FILL',
#   'orderID': '24',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'gainQuoteHomeConversionFactor': '0.860462405902',
#   'lossQuoteHomeConversionFactor': '0.869110269277',
#   'price': 1.15641,
#   'fullVWAP': 1.15641,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.1563, 'liquidity': '500000'},
#     {'price': 1.15629, 'liquidity': '500000'},
#     {'price': 1.15628, 'liquidity': '2000000'},
#     {'price': 1.15627, 'liquidity': '2000000'},
#     {'price': 1.15626, 'liquidity': '5000000'},
#     {'price': 1.15624, 'liquidity': '10000000'},
#     {'price': 1.15621, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15641, 'liquidity': '500000'},
#     {'price': 1.15643, 'liquidity': '2500000'},
#     {'price': 1.15644, 'liquidity': '2000000'},
#     {'price': 1.15645, 'liquidity': '5000000'},
#     {'price': 1.15648, 'liquidity': '10000000'},
#     {'price': 1.15651, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15621,
#    'closeoutAsk': 1.15651},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99997.9655',
#   'tradeOpened': {'tradeID': '25',
#    'units': '15000.0',
#    'price': 1.15641,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.7134',
#    'initialMarginRequired': '500.0'},
#   'halfSpreadCost': '0.7134'},
#  {'id': '26',
#   'time': '2025-11-11T09:26:19.222849902Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '24',
#   'requestID': '79451536175780492',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '25',
#   'price': 1.05641,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '27',
#   'time': '2025-11-11T09:27:47.011167135Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '27',
#   'requestID': '97465935053815249',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '28',
#   'time': '2025-11-11T09:27:47.011167135Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '27',
#   'requestID': '97465935053815249',
#   'type': 'ORDER_FILL',
#   'orderID': '27',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'gainQuoteHomeConversionFactor': '0.860469846098',
#   'lossQuoteHomeConversionFactor': '0.869117784249',
#   'price': 1.1563,
#   'fullVWAP': 1.1563,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.1563, 'liquidity': '500000'},
#     {'price': 1.15629, 'liquidity': '500000'},
#     {'price': 1.15628, 'liquidity': '2000000'},
#     {'price': 1.15627, 'liquidity': '2000000'},
#     {'price': 1.15626, 'liquidity': '5000000'},
#     {'price': 1.15624, 'liquidity': '10000000'},
#     {'price': 1.15621, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15639, 'liquidity': '500000'},
#     {'price': 1.15641, 'liquidity': '2500000'},
#     {'price': 1.15642, 'liquidity': '2000000'},
#     {'price': 1.15643, 'liquidity': '5000000'},
#     {'price': 1.15646, 'liquidity': '10000000'},
#     {'price': 1.15649, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15621,
#    'closeoutAsk': 1.15649},
#   'reason': 'MARKET_ORDER',
#   'pl': '-1.434',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99996.5315',
#   'tradesClosed': [{'tradeID': '25',
#     'units': '-15000.0',
#     'price': 1.1563,
#     'realizedPL': '-1.434',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.5837'}],
#   'halfSpreadCost': '0.5837'},
#  {'id': '29',
#   'time': '2025-11-11T09:27:47.011167135Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '27',
#   'requestID': '97465935053815249',
#   'type': 'ORDER_CANCEL',
#   'orderID': '26',
#   'reason': 'LINKED_TRADE_CLOSED'},
#  {'id': '30',
#   'time': '2025-11-11T09:45:37.525499230Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '30',
#   'requestID': '79451541037745808',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '31',
#   'time': '2025-11-11T09:45:37.525499230Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '30',
#   'requestID': '79451541037745808',
#   'type': 'ORDER_FILL',
#   'orderID': '30',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'gainQuoteHomeConversionFactor': '0.860231791723',
#   'lossQuoteHomeConversionFactor': '0.868877337369',
#   'price': 1.15661,
#   'fullVWAP': 1.15661,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15661, 'liquidity': '500000'},
#     {'price': 1.1566, 'liquidity': '500000'},
#     {'price': 1.15659, 'liquidity': '2000000'},
#     {'price': 1.15658, 'liquidity': '2000000'},
#     {'price': 1.15657, 'liquidity': '5000000'},
#     {'price': 1.15655, 'liquidity': '10000000'},
#     {'price': 1.15652, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15672, 'liquidity': '500000'},
#     {'price': 1.15674, 'liquidity': '2500000'},
#     {'price': 1.15675, 'liquidity': '2000000'},
#     {'price': 1.15676, 'liquidity': '5000000'},
#     {'price': 1.15679, 'liquidity': '10000000'},
#     {'price': 1.15682, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15652,
#    'closeoutAsk': 1.15682},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99996.5315',
#   'tradeOpened': {'tradeID': '31',
#    'units': '-15000.0',
#    'price': 1.15661,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.7133',
#    'initialMarginRequired': '500.0'},
#   'halfSpreadCost': '0.7133'},
#  {'id': '32',
#   'time': '2025-11-11T09:45:37.525499230Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '30',
#   'requestID': '79451541037745808',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '31',
#   'price': 1.25661,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '33',
#   'time': '2025-11-11T09:46:47.115813077Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '33',
#   'requestID': '97465939840373587',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '34',
#   'time': '2025-11-11T09:46:47.115813077Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '33',
#   'requestID': '97465939840373587',
#   'type': 'ORDER_FILL',
#   'orderID': '33',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'gainQuoteHomeConversionFactor': '0.860272697591',
#   'lossQuoteHomeConversionFactor': '0.86891865435',
#   'price': 1.15666,
#   'fullVWAP': 1.15666,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15656, 'liquidity': '500000'},
#     {'price': 1.15655, 'liquidity': '500000'},
#     {'price': 1.15654, 'liquidity': '2000000'},
#     {'price': 1.15653, 'liquidity': '2000000'},
#     {'price': 1.15652, 'liquidity': '5000000'},
#     {'price': 1.1565, 'liquidity': '10000000'},
#     {'price': 1.15647, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15666, 'liquidity': '500000'},
#     {'price': 1.15668, 'liquidity': '2500000'},
#     {'price': 1.15669, 'liquidity': '2000000'},
#     {'price': 1.1567, 'liquidity': '5000000'},
#     {'price': 1.15673, 'liquidity': '10000000'},
#     {'price': 1.15676, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15647,
#    'closeoutAsk': 1.15676},
#   'reason': 'MARKET_ORDER',
#   'pl': '-0.6517',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99995.8798',
#   'tradesClosed': [{'tradeID': '31',
#     'units': '15000.0',
#     'price': 1.15666,
#     'realizedPL': '-0.6517',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.6484'}],
#   'halfSpreadCost': '0.6484'},
#  {'id': '35',
#   'time': '2025-11-11T09:46:47.115813077Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '33',
#   'requestID': '97465939840373587',
#   'type': 'ORDER_CANCEL',
#   'orderID': '32',
#   'reason': 'LINKED_TRADE_CLOSED'},
#  {'id': '36',
#   'time': '2025-11-11T09:47:52.150024697Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '36',
#   'requestID': '97465940113051704',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '37',
#   'time': '2025-11-11T09:47:52.150024697Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '36',
#   'requestID': '97465940113051704',
#   'type': 'ORDER_FILL',
#   'orderID': '36',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'gainQuoteHomeConversionFactor': '0.860194606436',
#   'lossQuoteHomeConversionFactor': '0.868839778359',
#   'price': 1.15667,
#   'fullVWAP': 1.15667,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15667, 'liquidity': '500000'},
#     {'price': 1.15666, 'liquidity': '500000'},
#     {'price': 1.15665, 'liquidity': '2000000'},
#     {'price': 1.15664, 'liquidity': '2000000'},
#     {'price': 1.15663, 'liquidity': '5000000'},
#     {'price': 1.15661, 'liquidity': '10000000'},
#     {'price': 1.15658, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15676, 'liquidity': '500000'},
#     {'price': 1.15678, 'liquidity': '2500000'},
#     {'price': 1.15679, 'liquidity': '2000000'},
#     {'price': 1.1568, 'liquidity': '5000000'},
#     {'price': 1.15683, 'liquidity': '10000000'},
#     {'price': 1.15686, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15658,
#    'closeoutAsk': 1.15686},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99995.8798',
#   'tradeOpened': {'tradeID': '37',
#    'units': '-15000.0',
#    'price': 1.15667,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.5835',
#    'initialMarginRequired': '500.0'},
#   'halfSpreadCost': '0.5835'},
#  {'id': '38',
#   'time': '2025-11-11T09:47:52.150024697Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '36',
#   'requestID': '97465940113051704',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '37',
#   'price': 1.25667,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '39',
#   'time': '2025-11-11T09:48:37.934741768Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '39',
#   'requestID': '61437143281201404',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '40',
#   'time': '2025-11-11T09:48:37.934741768Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '39',
#   'requestID': '61437143281201404',
#   'type': 'ORDER_FILL',
#   'orderID': '39',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'gainQuoteHomeConversionFactor': '0.860239228961',
#   'lossQuoteHomeConversionFactor': '0.868884849352',
#   'price': 1.15671,
#   'fullVWAP': 1.15671,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.1566, 'liquidity': '500000'},
#     {'price': 1.15659, 'liquidity': '500000'},
#     {'price': 1.15658, 'liquidity': '2000000'},
#     {'price': 1.15657, 'liquidity': '2000000'},
#     {'price': 1.15656, 'liquidity': '5000000'},
#     {'price': 1.15654, 'liquidity': '10000000'},
#     {'price': 1.15651, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15671, 'liquidity': '500000'},
#     {'price': 1.15673, 'liquidity': '2500000'},
#     {'price': 1.15674, 'liquidity': '2000000'},
#     {'price': 1.15675, 'liquidity': '5000000'},
#     {'price': 1.15678, 'liquidity': '10000000'},
#     {'price': 1.15681, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15651,
#    'closeoutAsk': 1.15681},
#   'reason': 'MARKET_ORDER',
#   'pl': '-0.5213',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99995.3585',
#   'tradesClosed': [{'tradeID': '37',
#     'units': '15000.0',
#     'price': 1.15671,
#     'realizedPL': '-0.5213',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.7133'}],
#   'halfSpreadCost': '0.7133'},
#  {'id': '41',
#   'time': '2025-11-11T09:48:37.934741768Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '39',
#   'requestID': '61437143281201404',
#   'type': 'ORDER_CANCEL',
#   'orderID': '38',
#   'reason': 'LINKED_TRADE_CLOSED'},
#  {'id': '42',
#   'time': '2025-11-11T09:49:03.688897399Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '42',
#   'requestID': '61437143390268644',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '43',
#   'time': '2025-11-11T09:49:03.688897399Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '42',
#   'requestID': '61437143390268644',
#   'type': 'ORDER_FILL',
#   'orderID': '42',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'gainQuoteHomeConversionFactor': '0.860257822087',
#   'lossQuoteHomeConversionFactor': '0.868903629344',
#   'price': 1.15668,
#   'fullVWAP': 1.15668,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15658, 'liquidity': '500000'},
#     {'price': 1.15657, 'liquidity': '500000'},
#     {'price': 1.15656, 'liquidity': '2000000'},
#     {'price': 1.15655, 'liquidity': '2000000'},
#     {'price': 1.15654, 'liquidity': '5000000'},
#     {'price': 1.15652, 'liquidity': '10000000'},
#     {'price': 1.15649, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15668, 'liquidity': '500000'},
#     {'price': 1.1567, 'liquidity': '2500000'},
#     {'price': 1.15671, 'liquidity': '2000000'},
#     {'price': 1.15672, 'liquidity': '5000000'},
#     {'price': 1.15675, 'liquidity': '10000000'},
#     {'price': 1.15678, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15649,
#    'closeoutAsk': 1.15678},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99995.3585',
#   'tradeOpened': {'tradeID': '43',
#    'units': '15000.0',
#    'price': 1.15668,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.6484',
#    'initialMarginRequired': '500.0'},
#   'halfSpreadCost': '0.6484'},
#  {'id': '44',
#   'time': '2025-11-11T09:49:03.688897399Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '42',
#   'requestID': '61437143390268644',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '43',
#   'price': 1.05668,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '45',
#   'time': '2025-11-11T09:49:29.352885223Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '45',
#   'requestID': '97465940519967746',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '46',
#   'time': '2025-11-11T09:49:29.352885223Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '45',
#   'requestID': '97465940519967746',
#   'type': 'ORDER_FILL',
#   'orderID': '45',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'gainQuoteHomeConversionFactor': '0.860309888601',
#   'lossQuoteHomeConversionFactor': '0.86895621914',
#   'price': 1.15661,
#   'fullVWAP': 1.15661,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15651, 'liquidity': '500000'},
#     {'price': 1.1565, 'liquidity': '500000'},
#     {'price': 1.15649, 'liquidity': '2000000'},
#     {'price': 1.15648, 'liquidity': '2000000'},
#     {'price': 1.15647, 'liquidity': '5000000'},
#     {'price': 1.15645, 'liquidity': '10000000'},
#     {'price': 1.15642, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15661, 'liquidity': '500000'},
#     {'price': 1.15663, 'liquidity': '2500000'},
#     {'price': 1.15664, 'liquidity': '2000000'},
#     {'price': 1.15665, 'liquidity': '5000000'},
#     {'price': 1.15668, 'liquidity': '10000000'},
#     {'price': 1.15671, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15642,
#    'closeoutAsk': 1.15671},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99995.3585',
#   'tradeOpened': {'tradeID': '46',
#    'units': '15000.0',
#    'price': 1.15661,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.6485',
#    'initialMarginRequired': '500.0'},
#   'halfSpreadCost': '0.6485'},
#  {'id': '47',
#   'time': '2025-11-11T09:49:29.352885223Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '45',
#   'requestID': '97465940519967746',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '46',
#   'price': 1.05661,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '48',
#   'time': '2025-11-11T09:49:44.889704838Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '48',
#   'requestID': '79451542073899523',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '49',
#   'time': '2025-11-11T09:49:44.889704838Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '48',
#   'requestID': '79451542073899523',
#   'type': 'ORDER_FILL',
#   'orderID': '48',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'gainQuoteHomeConversionFactor': '0.860335924753',
#   'lossQuoteHomeConversionFactor': '0.868982516961',
#   'price': 1.15647,
#   'fullVWAP': 1.15647,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15647, 'liquidity': '500000'},
#     {'price': 1.15646, 'liquidity': '500000'},
#     {'price': 1.15645, 'liquidity': '2000000'},
#     {'price': 1.15644, 'liquidity': '2000000'},
#     {'price': 1.15643, 'liquidity': '5000000'},
#     {'price': 1.15641, 'liquidity': '10000000'},
#     {'price': 1.15638, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15658, 'liquidity': '500000'},
#     {'price': 1.1566, 'liquidity': '2500000'},
#     {'price': 1.15661, 'liquidity': '2000000'},
#     {'price': 1.15662, 'liquidity': '5000000'},
#     {'price': 1.15665, 'liquidity': '10000000'},
#     {'price': 1.15668, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15638,
#    'closeoutAsk': 1.15668},
#   'reason': 'MARKET_ORDER',
#   'pl': '-2.7373',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99992.6212',
#   'tradesClosed': [{'tradeID': '43',
#     'units': '-15000.0',
#     'price': 1.15647,
#     'realizedPL': '-2.7373',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.7133'}],
#   'halfSpreadCost': '0.7133'},
#  {'id': '50',
#   'time': '2025-11-11T09:49:44.889704838Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '48',
#   'requestID': '79451542073899523',
#   'type': 'ORDER_CANCEL',
#   'orderID': '44',
#   'reason': 'LINKED_TRADE_CLOSED'},
#  {'id': '51',
#   'time': '2025-11-11T09:49:50.702949431Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '51',
#   'requestID': '61437143587429294',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '52',
#   'time': '2025-11-11T09:49:50.702949431Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '51',
#   'requestID': '61437143587429294',
#   'type': 'ORDER_FILL',
#   'orderID': '51',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'gainQuoteHomeConversionFactor': '0.860350801929',
#   'lossQuoteHomeConversionFactor': '0.868997543657',
#   'price': 1.15646,
#   'fullVWAP': 1.15646,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15646, 'liquidity': '500000'},
#     {'price': 1.15645, 'liquidity': '500000'},
#     {'price': 1.15644, 'liquidity': '2000000'},
#     {'price': 1.15643, 'liquidity': '2000000'},
#     {'price': 1.15642, 'liquidity': '5000000'},
#     {'price': 1.1564, 'liquidity': '10000000'},
#     {'price': 1.15637, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15655, 'liquidity': '500000'},
#     {'price': 1.15657, 'liquidity': '2500000'},
#     {'price': 1.15658, 'liquidity': '2000000'},
#     {'price': 1.15659, 'liquidity': '5000000'},
#     {'price': 1.15662, 'liquidity': '10000000'},
#     {'price': 1.15665, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15637,
#    'closeoutAsk': 1.15665},
#   'reason': 'MARKET_ORDER',
#   'pl': '-1.9552',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99990.666',
#   'tradesClosed': [{'tradeID': '46',
#     'units': '-15000.0',
#     'price': 1.15646,
#     'realizedPL': '-1.9552',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.5837'}],
#   'halfSpreadCost': '0.5837'},
#  {'id': '53',
#   'time': '2025-11-11T09:49:50.702949431Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '51',
#   'requestID': '61437143587429294',
#   'type': 'ORDER_CANCEL',
#   'orderID': '47',
#   'reason': 'LINKED_TRADE_CLOSED'},
#  {'id': '54',
#   'time': '2025-11-11T09:49:59.874247367Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '54',
#   'requestID': '97465940645818138',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '55',
#   'time': '2025-11-11T09:49:59.874247367Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '54',
#   'requestID': '97465940645818138',
#   'type': 'ORDER_FILL',
#   'orderID': '54',
#   'instrument': 'EUR_USD',
#   'units': '15000.0',
#   'gainQuoteHomeConversionFactor': '0.860343363791',
#   'lossQuoteHomeConversionFactor': '0.868990030764',
#   'price': 1.15657,
#   'fullVWAP': 1.15657,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15646, 'liquidity': '500000'},
#     {'price': 1.15645, 'liquidity': '500000'},
#     {'price': 1.15644, 'liquidity': '2000000'},
#     {'price': 1.15643, 'liquidity': '2000000'},
#     {'price': 1.15642, 'liquidity': '5000000'},
#     {'price': 1.1564, 'liquidity': '10000000'},
#     {'price': 1.15637, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15657, 'liquidity': '500000'},
#     {'price': 1.15659, 'liquidity': '2500000'},
#     {'price': 1.1566, 'liquidity': '2000000'},
#     {'price': 1.15661, 'liquidity': '5000000'},
#     {'price': 1.15664, 'liquidity': '10000000'},
#     {'price': 1.15667, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15637,
#    'closeoutAsk': 1.15667},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99990.666',
#   'tradeOpened': {'tradeID': '55',
#    'units': '15000.0',
#    'price': 1.15657,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.7134',
#    'initialMarginRequired': '500.0'},
#   'halfSpreadCost': '0.7134'},
#  {'id': '56',
#   'time': '2025-11-11T09:49:59.874247367Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '54',
#   'requestID': '97465940645818138',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '55',
#   'price': 1.05657,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '57',
#   'time': '2025-11-11T09:53:45.916924018Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '57',
#   'requestID': '115480340104913022',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '58',
#   'time': '2025-11-11T09:53:45.916924018Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '57',
#   'requestID': '115480340104913022',
#   'type': 'ORDER_FILL',
#   'orderID': '57',
#   'instrument': 'EUR_USD',
#   'units': '-15000.0',
#   'gainQuoteHomeConversionFactor': '0.860228071658',
#   'lossQuoteHomeConversionFactor': '0.868873579915',
#   'price': 1.15663,
#   'fullVWAP': 1.15663,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.15663, 'liquidity': '500000'},
#     {'price': 1.15662, 'liquidity': '500000'},
#     {'price': 1.15661, 'liquidity': '2000000'},
#     {'price': 1.1566, 'liquidity': '2000000'},
#     {'price': 1.15659, 'liquidity': '5000000'},
#     {'price': 1.15657, 'liquidity': '10000000'},
#     {'price': 1.15654, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.15671, 'liquidity': '500000'},
#     {'price': 1.15673, 'liquidity': '2500000'},
#     {'price': 1.15674, 'liquidity': '2000000'},
#     {'price': 1.15675, 'liquidity': '5000000'},
#     {'price': 1.15678, 'liquidity': '10000000'},
#     {'price': 1.15681, 'liquidity': '10000000'}],
#    'closeoutBid': 1.15654,
#    'closeoutAsk': 1.15681},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.7742',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99991.4402',
#   'tradesClosed': [{'tradeID': '55',
#     'units': '-15000.0',
#     'price': 1.15663,
#     'realizedPL': '0.7742',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.5187'}],
#   'halfSpreadCost': '0.5187'},
#  {'id': '59',
#   'time': '2025-11-11T09:53:45.916924018Z',
#   'userID': 37633556,
#   'accountID': '101-011-37633556-002',
#   'batchID': '57',
#   'requestID': '115480340104913022',
#   'type': 'ORDER_CANCEL',
#   'orderID': '56',
#   'reason': 'LINKED_TRADE_CLOSED'}]

# %%
api.print_transactions(tid = 1) # insert the id of the first trade in this session
# Out:
#    5 | 2025-11-10T14:02:32.69 | EUR_USD |   1000.0 |      0.0
#    7 | 2025-11-10T14:03:08.29 | EUR_USD |  -1000.0 |  -0.2172
#    9 | 2025-11-10T14:04:11.39 | EUR_USD |  10000.0 |      0.0
#   11 | 2025-11-10T14:06:01.14 | EUR_USD | -10000.0 |  -1.6511
#   13 | 2025-11-10T14:06:10.10 | EUR_USD |  10000.0 |      0.0
#   15 | 2025-11-10T14:09:16.01 | EUR_USD | -10000.0 |  -0.2607
#   17 | 2025-11-10T14:09:28.53 | EUR_USD |      1.0 |      0.0
#   19 | 2025-11-10T14:09:35.59 | EUR_USD |     -1.0 |  -0.0001
#   21 | 2025-11-10T14:09:41.41 | EUR_USD |   1000.0 |      0.0
#   23 | 2025-11-10T14:10:31.13 | EUR_USD |  -1000.0 |   0.0946
#   25 | 2025-11-11T09:26:19.22 | EUR_USD |  15000.0 |      0.0
#   28 | 2025-11-11T09:27:47.01 | EUR_USD | -15000.0 |   -1.434
#   31 | 2025-11-11T09:45:37.52 | EUR_USD | -15000.0 |      0.0
#   34 | 2025-11-11T09:46:47.11 | EUR_USD |  15000.0 |  -0.6517
#   37 | 2025-11-11T09:47:52.15 | EUR_USD | -15000.0 |      0.0
#   40 | 2025-11-11T09:48:37.93 | EUR_USD |  15000.0 |  -0.5213
#   43 | 2025-11-11T09:49:03.68 | EUR_USD |  15000.0 |      0.0
#   46 | 2025-11-11T09:49:29.35 | EUR_USD |  15000.0 |      0.0
#   49 | 2025-11-11T09:49:44.88 | EUR_USD | -15000.0 |  -2.7373
#   52 | 2025-11-11T09:49:50.70 | EUR_USD | -15000.0 |  -1.9552
#   55 | 2025-11-11T09:49:59.87 | EUR_USD |  15000.0 |      0.0
#   58 | 2025-11-11T09:53:45.91 | EUR_USD | -15000.0 |   0.7742
#   61 | 2025-11-11T09:54:31.08 | EUR_USD | -15000.0 |      0.0
#   64 | 2025-11-11T09:55:31.65 | EUR_USD |  15000.0 |   0.1291
#   67 | 2025-11-11T09:59:35.96 | EUR_USD | -99900.0 |      0.0
#   70 | 2025-11-11T10:00:04.77 | EUR_USD |  99900.0 |  14.6126
#   73 | 2025-11-11T10:02:52.94 | EUR_USD | -99900.0 |      0.0
#   76 | 2025-11-11T10:04:20.23 | EUR_USD |  99900.0 |   9.4548
