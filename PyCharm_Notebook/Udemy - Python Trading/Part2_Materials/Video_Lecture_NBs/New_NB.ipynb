# %%
import FinancialInstrument as FI

# %%
stock = FI.FinancialInstrument("AAPL", "2015-01-01", "2018-01-01")
# Out:
# C:\Users\bedla\Documents\Ausbildung_Informatik\1_Praktikum\Praktikum_Daten-_und_Prozessanalyse\energy_trading\PyCharm_Notebook\Udemy - Python Trading\Part2_Materials\Video_Lecture_NBs\FinancialInstrument.py:57: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self._ticker, self.start, self.end, multi_level_index = False).Close.to_frame()
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
# FinancialInstrument(ticker = AAPL, start = 2015-01-01, end = 2018-01-01)

# %%
stock.data
# Out:
#                 price  log_returns
# Date
# 2015-01-02  24.237556          NaN
# 2015-01-05  23.554739    -0.028576
# 2015-01-06  23.556957     0.000094
# 2015-01-07  23.887274     0.013925
# 2015-01-08  24.805084     0.037703
# ...               ...          ...
# 2017-12-22  40.985916     0.000000
# 2017-12-26  39.946117    -0.025697
# 2017-12-27  39.953133     0.000176
# 2017-12-28  40.065544     0.002810
# 2017-12-29  39.632294    -0.010872
#
# [755 rows x 2 columns]
