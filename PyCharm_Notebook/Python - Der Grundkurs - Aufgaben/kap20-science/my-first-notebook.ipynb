# %%
s='Hello, Jupyter!'
print(s)
# Out:
# Hello, Jupyter!

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.randn(3, 3)

# %%
data
# Out:
# array([[-0.33412872, -0.56974505, -1.16203972],
#        [ 0.84209574, -1.28718005, -0.13624637],
#        [-0.53448661,  1.86152966, -2.29524581]])

# %%
plt.imshow(data, interpolation='nearest')
