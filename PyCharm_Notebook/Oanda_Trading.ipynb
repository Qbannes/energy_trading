# %%
import pandas as pd
import tpqoa
api = tpqoa.tpqoa("oanda.cfg")

# %%
api = tpqoa.tpqoa("oanda.cfg")
api.get_account_summary()
# Out:
# {'id': '101-011-37633556-002',
#  'alias': 'Konto2',
#  'currency': 'EUR',
#  'balance': '99773.4227',
#  'createdByUserID': 37633556,
#  'createdTime': '2025-11-10T13:42:43.019655832Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '-218.2887',
#  'resettablePL': '-218.2887',
#  'resettablePLTime': '0',
#  'financing': '-8.2886',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.03333333333333',
#  'openTradeCount': 1,
#  'openPositionCount': 1,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '-392.384',
#  'NAV': '99381.0387',
#  'marginUsed': '33333.3333',
#  'marginAvailable': '66093.0389',
#  'positionValue': '1000000.0',
#  'marginCloseoutUnrealizedPL': '-347.0505',
#  'marginCloseoutNAV': '99426.3722',
#  'marginCloseoutMarginUsed': '33333.3333',
#  'marginCloseoutPercent': '0.16763',
#  'marginCloseoutPositionValue': '1000000.0',
#  'withdrawalLimit': '66093.0389',
#  'marginCallMarginUsed': '33333.3333',
#  'marginCallPercent': '0.33526',
#  'lastTransactionID': '210'}

# %%
api.account_id
# Out:
# '101-011-37633556-002'

# %%
api.account_type
# Out:
# 'practice'

# %%
api.get_instruments()
instr = api.get_instruments()

# %%
# api.stream_data('EUR_USD', stop = 10)
# api.stream_data('EUR_USD') # without stop marker
# api.stop_stream()

# %%
# api.create_order(instrument = "EUR_USD", units = 99000, sl_distance= 0.1)
# api.create_order(instrument = "EUR_USD", units = -99000, sl_distance= 0.1)

# %%
transa_df = pd.DataFrame(api.get_transactions())
# Datumsformatierung der Spalte time und Zuweisung von Datum und Uhrzeit aus der Spalte time den neuen Spalten datum und uhrzeit
transa_df['time'] = pd.to_datetime(transa_df['time'], utc=True)
transa_df['datum'] = transa_df['time'].dt.date
transa_df['uhrzeit'] = transa_df['time'].dt.time

# Spalte 'time' entfernen
transa_df = transa_df.drop(columns=['time'])
# Spalten neu anordnen: datum an Index 2, uhrzeit an Index 3
cols = list(transa_df.columns)
# Entfernen der neuen Spalten aus der Liste, falls sie nicht am gewünschten Platz sind
cols.remove('datum')
cols.remove('uhrzeit')
# Einfügen an Indexposition 2 und 3
cols.insert(2, 'datum')
cols.insert(3, 'uhrzeit')
# Geänderte Spalten dem DataFrame zuweisen
transa_df=transa_df[cols]
# DataFrame nach Spalte 'datum' absteigend sortieren
transa_df = transa_df.sort_values(by='datum', ascending=False)
# Optional: Index zurücksetzen, damit die Zeilennummern durchgehend sind
# transa_df = transa_df.reset_index(drop=True)

transa_df.to_csv('Transaktionsdaten.csv', sep=';', index=False)
pd.read_csv('Transaktionsdaten.csv', sep=';')
# Out:
#       id    userID       datum          uhrzeit             accountID  \
# 0    210  37633556  2025-11-20  09:45:23.481996  101-011-37633556-002
# 1    200  37633556  2025-11-20  09:00:17.778971  101-011-37633556-002
# 2    191  37633556  2025-11-20  06:53:04.962223  101-011-37633556-002
# 3    192  37633556  2025-11-20  06:53:04.962223  101-011-37633556-002
# 4    193  37633556  2025-11-20  06:53:38.504182  101-011-37633556-002
# ..   ...       ...         ...              ...                   ...
# 205   20  37633556  2025-11-10  14:09:41.416303  101-011-37633556-002
# 206   21  37633556  2025-11-10  14:09:41.416303  101-011-37633556-002
# 207   22  37633556  2025-11-10  14:10:31.133081  101-011-37633556-002
# 208   23  37633556  2025-11-10  14:10:31.133081  101-011-37633556-002
# 209    1  37633556  2025-11-10  13:42:43.019655  101-011-37633556-002
#
#      batchID     requestID          type  divisionID  siteID  ...  \
# 0        209  1.154836e+17    ORDER_FILL         NaN     NaN  ...
# 1        199  6.144039e+16    ORDER_FILL         NaN     NaN  ...
# 2        191  9.746916e+16  MARKET_ORDER         NaN     NaN  ...
# 3        191  9.746916e+16    ORDER_FILL         NaN     NaN  ...
# 4        193  9.746916e+16  MARKET_ORDER         NaN     NaN  ...
# ..       ...           ...           ...         ...     ...  ...
# 205       20  9.746564e+16  MARKET_ORDER         NaN     NaN  ...
# 206       20  9.746564e+16    ORDER_FILL         NaN     NaN  ...
# 207       22  7.945125e+16  MARKET_ORDER         NaN     NaN  ...
# 208       22  7.945125e+16    ORDER_FILL         NaN     NaN  ...
# 209        1  1.610675e+18        CREATE        11.0   101.0  ...
#
#      halfSpreadCost                          tradeClose  \
# 0           52.0725                                 NaN
# 1            3.9012                                 NaN
# 2               NaN                                 NaN
# 3            4.7983                                 NaN
# 4               NaN                                 NaN
# ..              ...                                 ...
# 205             NaN                                 NaN
# 206          0.0476                                 NaN
# 207             NaN  {'tradeID': '21', 'units': '1000'}
# 208          0.0389                                 NaN
# 209             NaN                                 NaN
#
#                                           tradesClosed stopLossOnFill  \
# 0                                                  NaN            NaN
# 1    [{'tradeID': '198', 'units': '-99879.0', 'pric...            NaN
# 2                                                  NaN            NaN
# 3    [{'tradeID': '189', 'units': '-100510.0', 'pri...            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 205                                                NaN            NaN
# 206                                                NaN            NaN
# 207                                                NaN            NaN
# 208  [{'tradeID': '21', 'units': '-1000.0', 'price'...            NaN
# 209                                                NaN            NaN
#
#      tradeID  distance triggerCondition  \
# 0        NaN       NaN              NaN
# 1        NaN       NaN              NaN
# 2        NaN       NaN              NaN
# 3        NaN       NaN              NaN
# 4        NaN       NaN              NaN
# ..       ...       ...              ...
# 205      NaN       NaN              NaN
# 206      NaN       NaN              NaN
# 207      NaN       NaN              NaN
# 208      NaN       NaN              NaN
# 209      NaN       NaN              NaN
#
#                           longPositionCloseout shortPositionCloseout  \
# 0                                          NaN                   NaN
# 1                                          NaN                   NaN
# 2    {'instrument': 'EUR_USD', 'units': 'ALL'}                   NaN
# 3                                          NaN                   NaN
# 4                                          NaN                   NaN
# ..                                         ...                   ...
# 205                                        NaN                   NaN
# 206                                        NaN                   NaN
# 207                                        NaN                   NaN
# 208                                        NaN                   NaN
# 209                                        NaN                   NaN
#
#      positionFinancings
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 205                 NaN
# 206                 NaN
# 207                 NaN
# 208                 NaN
# 209                 NaN
#
# [210 rows x 44 columns]
