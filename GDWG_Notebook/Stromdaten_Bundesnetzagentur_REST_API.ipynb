# %%
# Zelle 1: Bibliotheken importieren
import requests
import pandas as pd
from datetime import datetime, timedelta
import json
import time

print("Bibliotheken erfolgreich importiert!")
# Out:
# Bibliotheken erfolgreich importiert!

# %%
# Zelle 2: Konfiguration und Hilfsfunktionen
# API-Basis-URL
BASE_URL = "https://www.smard.de/app/chart_data"

# Filter-Code für Strompreise (Day-Ahead Auktion)
FILTER_STROMPREIS = 4169

# Region Deutschland
REGION = "DE"

# Auflösung (hour, quarterhour, day, week, month, year)
RESOLUTION = "quarterhour"

def unix_timestamp_ms(dt):
    """Konvertiert datetime zu Unix-Timestamp in Millisekunden"""
    return int(dt.timestamp() * 1000)

def get_available_timestamps(filter_code, region, resolution):
    """
    Ruft verfügbare Timestamps für einen Filter ab
    """
    url = f"{BASE_URL}/{filter_code}/{region}/index_{resolution}.json"
    print(f"Rufe verfügbare Timestamps ab: {url}")
    
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        timestamps = data.get('timestamps', [])
        print(f" {len(timestamps)} verfügbare Zeitstempel gefunden")
        return timestamps
    else:
        print(f" Fehler beim Abrufen der Timestamps: {response.status_code}")
        return []

print("Konfiguration und Hilfsfunktionen geladen!")
# Out:
# Konfiguration und Hilfsfunktionen geladen!

# %%
# Zelle 3: Verfügbare Timestamps abrufen
print(f"Filter: {FILTER_STROMPREIS} (Strompreise)")
print(f"Region: {REGION}")
print(f"Auflösung: {RESOLUTION}")
print("-" * 60)

timestamps = get_available_timestamps(FILTER_STROMPREIS, REGION, RESOLUTION)

if timestamps:
    print(f"\nErster Timestamp: {timestamps[0]} ({datetime.fromtimestamp(timestamps[0]/1000)})")
    print(f"Letzter Timestamp: {timestamps[-1]} ({datetime.fromtimestamp(timestamps[-1]/1000)})")
    print(f"\nInsgesamt {len(timestamps)} Zeitstempel verfügbar")
# Out:
# Filter: 4169 (Strompreise)
# Region: DE
# Auflösung: quarterhour
# ------------------------------------------------------------
# Rufe verfügbare Timestamps ab: https://www.smard.de/app/chart_data/4169/DE/index_quarterhour.json
#  372 verfügbare Zeitstempel gefunden
#
# Erster Timestamp: 1538344800000 (2018-09-30 22:00:00)
# Letzter Timestamp: 1762729200000 (2025-11-09 23:00:00)
#
# Insgesamt 372 Zeitstempel verfügbar

# %%
# Zelle 4: Funktion zum Abrufen der Zeitreihendaten
def get_time_series_data(filter_code, region, resolution, timestamp):
    """
    Ruft Zeitreihendaten für einen bestimmten Timestamp ab
    """
    url = f"{BASE_URL}/{filter_code}/{region}/{filter_code}_{region}_{resolution}_{timestamp}.json"
    
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"✗ Fehler beim Abrufen der Daten für Timestamp {timestamp}: {response.status_code}")
        return None

def parse_time_series(data):
    """
    Parst die Zeitreihendaten in ein DataFrame
    """
    if data and 'series' in data:
        df = pd.DataFrame(data['series'], columns=['timestamp', 'value'])
        df['datetime'] = pd.to_datetime(df['timestamp'], unit='ms')
        return df
    return pd.DataFrame()

print("Funktionen zum Abrufen der Zeitreihendaten definiert!")
# Out:
# Funktionen zum Abrufen der Zeitreihendaten definiert!

# %%
# Zelle 5: Daten für einen bestimmten Zeitraum abrufen
# Beispiel: Daten der letzten 30 Tage abrufen
# (Du kannst die Anzahl der Timestamps anpassen)

# Anzahl der neuesten Timestamps, die abgerufen werden sollen
# NUM_TIMESTAMPS = 5  # Ändere diese Zahl für mehr oder weniger Daten
NUM_TIMESTAMPS = len(timestamps)
print(f"Rufe Daten für die letzten {NUM_TIMESTAMPS} Timestamps ab...")
print("-" * 60)

all_data = []

# Nehme die letzten NUM_TIMESTAMPS Zeitstempel
for idx, ts in enumerate(timestamps[-NUM_TIMESTAMPS:], 1):
    print(f"[{idx}/{NUM_TIMESTAMPS}] Rufe Daten ab für {datetime.fromtimestamp(ts/1000)}")
    
    data = get_time_series_data(FILTER_STROMPREIS, REGION, RESOLUTION, ts)
    
    if data:
        df = parse_time_series(data)
        all_data.append(df)
        print(f"  ✓ {len(df)} Datenpunkte abgerufen")
    
    # Kleine Pause, um die API nicht zu überlasten
    time.sleep(0.5)

print("\n" + "=" * 60)
print("Datenabruf abgeschlossen!")
# Out:
# Rufe Daten für die letzten 372 Timestamps ab...
# ------------------------------------------------------------
# [1/372] Rufe Daten ab für 2018-09-30 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [2/372] Rufe Daten ab für 2018-10-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [3/372] Rufe Daten ab für 2018-10-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [4/372] Rufe Daten ab für 2018-10-21 22:00:00
#   ✓ 676 Datenpunkte abgerufen
# [5/372] Rufe Daten ab für 2018-10-28 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [6/372] Rufe Daten ab für 2018-11-04 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [7/372] Rufe Daten ab für 2018-11-11 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [8/372] Rufe Daten ab für 2018-11-18 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [9/372] Rufe Daten ab für 2018-11-25 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [10/372] Rufe Daten ab für 2018-12-02 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [11/372] Rufe Daten ab für 2018-12-09 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [12/372] Rufe Daten ab für 2018-12-16 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [13/372] Rufe Daten ab für 2018-12-23 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [14/372] Rufe Daten ab für 2018-12-30 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [15/372] Rufe Daten ab für 2019-01-06 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [16/372] Rufe Daten ab für 2019-01-13 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [17/372] Rufe Daten ab für 2019-01-20 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [18/372] Rufe Daten ab für 2019-01-27 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [19/372] Rufe Daten ab für 2019-02-03 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [20/372] Rufe Daten ab für 2019-02-10 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [21/372] Rufe Daten ab für 2019-02-17 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [22/372] Rufe Daten ab für 2019-02-24 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [23/372] Rufe Daten ab für 2019-03-03 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [24/372] Rufe Daten ab für 2019-03-10 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [25/372] Rufe Daten ab für 2019-03-17 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [26/372] Rufe Daten ab für 2019-03-24 23:00:00
#   ✓ 668 Datenpunkte abgerufen
# [27/372] Rufe Daten ab für 2019-03-31 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [28/372] Rufe Daten ab für 2019-04-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [29/372] Rufe Daten ab für 2019-04-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [30/372] Rufe Daten ab für 2019-04-21 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [31/372] Rufe Daten ab für 2019-04-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [32/372] Rufe Daten ab für 2019-05-05 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [33/372] Rufe Daten ab für 2019-05-12 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [34/372] Rufe Daten ab für 2019-05-19 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [35/372] Rufe Daten ab für 2019-05-26 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [36/372] Rufe Daten ab für 2019-06-02 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [37/372] Rufe Daten ab für 2019-06-09 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [38/372] Rufe Daten ab für 2019-06-16 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [39/372] Rufe Daten ab für 2019-06-23 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [40/372] Rufe Daten ab für 2019-06-30 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [41/372] Rufe Daten ab für 2019-07-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [42/372] Rufe Daten ab für 2019-07-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [43/372] Rufe Daten ab für 2019-07-21 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [44/372] Rufe Daten ab für 2019-07-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [45/372] Rufe Daten ab für 2019-08-04 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [46/372] Rufe Daten ab für 2019-08-11 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [47/372] Rufe Daten ab für 2019-08-18 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [48/372] Rufe Daten ab für 2019-08-25 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [49/372] Rufe Daten ab für 2019-09-01 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [50/372] Rufe Daten ab für 2019-09-08 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [51/372] Rufe Daten ab für 2019-09-15 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [52/372] Rufe Daten ab für 2019-09-22 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [53/372] Rufe Daten ab für 2019-09-29 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [54/372] Rufe Daten ab für 2019-10-06 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [55/372] Rufe Daten ab für 2019-10-13 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [56/372] Rufe Daten ab für 2019-10-20 22:00:00
#   ✓ 676 Datenpunkte abgerufen
# [57/372] Rufe Daten ab für 2019-10-27 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [58/372] Rufe Daten ab für 2019-11-03 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [59/372] Rufe Daten ab für 2019-11-10 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [60/372] Rufe Daten ab für 2019-11-17 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [61/372] Rufe Daten ab für 2019-11-24 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [62/372] Rufe Daten ab für 2019-12-01 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [63/372] Rufe Daten ab für 2019-12-08 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [64/372] Rufe Daten ab für 2019-12-15 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [65/372] Rufe Daten ab für 2019-12-22 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [66/372] Rufe Daten ab für 2019-12-29 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [67/372] Rufe Daten ab für 2020-01-05 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [68/372] Rufe Daten ab für 2020-01-12 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [69/372] Rufe Daten ab für 2020-01-19 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [70/372] Rufe Daten ab für 2020-01-26 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [71/372] Rufe Daten ab für 2020-02-02 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [72/372] Rufe Daten ab für 2020-02-09 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [73/372] Rufe Daten ab für 2020-02-16 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [74/372] Rufe Daten ab für 2020-02-23 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [75/372] Rufe Daten ab für 2020-03-01 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [76/372] Rufe Daten ab für 2020-03-08 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [77/372] Rufe Daten ab für 2020-03-15 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [78/372] Rufe Daten ab für 2020-03-22 23:00:00
#   ✓ 668 Datenpunkte abgerufen
# [79/372] Rufe Daten ab für 2020-03-29 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [80/372] Rufe Daten ab für 2020-04-05 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [81/372] Rufe Daten ab für 2020-04-12 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [82/372] Rufe Daten ab für 2020-04-19 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [83/372] Rufe Daten ab für 2020-04-26 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [84/372] Rufe Daten ab für 2020-05-03 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [85/372] Rufe Daten ab für 2020-05-10 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [86/372] Rufe Daten ab für 2020-05-17 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [87/372] Rufe Daten ab für 2020-05-24 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [88/372] Rufe Daten ab für 2020-05-31 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [89/372] Rufe Daten ab für 2020-06-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [90/372] Rufe Daten ab für 2020-06-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [91/372] Rufe Daten ab für 2020-06-21 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [92/372] Rufe Daten ab für 2020-06-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [93/372] Rufe Daten ab für 2020-07-05 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [94/372] Rufe Daten ab für 2020-07-12 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [95/372] Rufe Daten ab für 2020-07-19 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [96/372] Rufe Daten ab für 2020-07-26 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [97/372] Rufe Daten ab für 2020-08-02 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [98/372] Rufe Daten ab für 2020-08-09 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [99/372] Rufe Daten ab für 2020-08-16 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [100/372] Rufe Daten ab für 2020-08-23 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [101/372] Rufe Daten ab für 2020-08-30 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [102/372] Rufe Daten ab für 2020-09-06 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [103/372] Rufe Daten ab für 2020-09-13 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [104/372] Rufe Daten ab für 2020-09-20 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [105/372] Rufe Daten ab für 2020-09-27 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [106/372] Rufe Daten ab für 2020-10-04 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [107/372] Rufe Daten ab für 2020-10-11 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [108/372] Rufe Daten ab für 2020-10-18 22:00:00
#   ✓ 676 Datenpunkte abgerufen
# [109/372] Rufe Daten ab für 2020-10-25 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [110/372] Rufe Daten ab für 2020-11-01 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [111/372] Rufe Daten ab für 2020-11-08 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [112/372] Rufe Daten ab für 2020-11-15 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [113/372] Rufe Daten ab für 2020-11-22 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [114/372] Rufe Daten ab für 2020-11-29 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [115/372] Rufe Daten ab für 2020-12-06 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [116/372] Rufe Daten ab für 2020-12-13 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [117/372] Rufe Daten ab für 2020-12-20 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [118/372] Rufe Daten ab für 2020-12-27 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [119/372] Rufe Daten ab für 2021-01-03 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [120/372] Rufe Daten ab für 2021-01-10 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [121/372] Rufe Daten ab für 2021-01-17 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [122/372] Rufe Daten ab für 2021-01-24 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [123/372] Rufe Daten ab für 2021-01-31 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [124/372] Rufe Daten ab für 2021-02-07 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [125/372] Rufe Daten ab für 2021-02-14 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [126/372] Rufe Daten ab für 2021-02-21 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [127/372] Rufe Daten ab für 2021-02-28 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [128/372] Rufe Daten ab für 2021-03-07 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [129/372] Rufe Daten ab für 2021-03-14 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [130/372] Rufe Daten ab für 2021-03-21 23:00:00
#   ✓ 668 Datenpunkte abgerufen
# [131/372] Rufe Daten ab für 2021-03-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [132/372] Rufe Daten ab für 2021-04-04 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [133/372] Rufe Daten ab für 2021-04-11 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [134/372] Rufe Daten ab für 2021-04-18 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [135/372] Rufe Daten ab für 2021-04-25 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [136/372] Rufe Daten ab für 2021-05-02 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [137/372] Rufe Daten ab für 2021-05-09 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [138/372] Rufe Daten ab für 2021-05-16 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [139/372] Rufe Daten ab für 2021-05-23 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [140/372] Rufe Daten ab für 2021-05-30 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [141/372] Rufe Daten ab für 2021-06-06 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [142/372] Rufe Daten ab für 2021-06-13 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [143/372] Rufe Daten ab für 2021-06-20 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [144/372] Rufe Daten ab für 2021-06-27 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [145/372] Rufe Daten ab für 2021-07-04 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [146/372] Rufe Daten ab für 2021-07-11 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [147/372] Rufe Daten ab für 2021-07-18 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [148/372] Rufe Daten ab für 2021-07-25 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [149/372] Rufe Daten ab für 2021-08-01 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [150/372] Rufe Daten ab für 2021-08-08 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [151/372] Rufe Daten ab für 2021-08-15 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [152/372] Rufe Daten ab für 2021-08-22 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [153/372] Rufe Daten ab für 2021-08-29 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [154/372] Rufe Daten ab für 2021-09-05 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [155/372] Rufe Daten ab für 2021-09-12 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [156/372] Rufe Daten ab für 2021-09-19 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [157/372] Rufe Daten ab für 2021-09-26 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [158/372] Rufe Daten ab für 2021-10-03 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [159/372] Rufe Daten ab für 2021-10-10 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [160/372] Rufe Daten ab für 2021-10-17 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [161/372] Rufe Daten ab für 2021-10-24 22:00:00
#   ✓ 676 Datenpunkte abgerufen
# [162/372] Rufe Daten ab für 2021-10-31 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [163/372] Rufe Daten ab für 2021-11-07 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [164/372] Rufe Daten ab für 2021-11-14 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [165/372] Rufe Daten ab für 2021-11-21 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [166/372] Rufe Daten ab für 2021-11-28 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [167/372] Rufe Daten ab für 2021-12-05 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [168/372] Rufe Daten ab für 2021-12-12 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [169/372] Rufe Daten ab für 2021-12-19 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [170/372] Rufe Daten ab für 2021-12-26 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [171/372] Rufe Daten ab für 2022-01-02 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [172/372] Rufe Daten ab für 2022-01-09 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [173/372] Rufe Daten ab für 2022-01-16 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [174/372] Rufe Daten ab für 2022-01-23 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [175/372] Rufe Daten ab für 2022-01-30 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [176/372] Rufe Daten ab für 2022-02-06 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [177/372] Rufe Daten ab für 2022-02-13 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [178/372] Rufe Daten ab für 2022-02-20 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [179/372] Rufe Daten ab für 2022-02-27 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [180/372] Rufe Daten ab für 2022-03-06 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [181/372] Rufe Daten ab für 2022-03-13 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [182/372] Rufe Daten ab für 2022-03-20 23:00:00
#   ✓ 668 Datenpunkte abgerufen
# [183/372] Rufe Daten ab für 2022-03-27 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [184/372] Rufe Daten ab für 2022-04-03 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [185/372] Rufe Daten ab für 2022-04-10 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [186/372] Rufe Daten ab für 2022-04-17 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [187/372] Rufe Daten ab für 2022-04-24 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [188/372] Rufe Daten ab für 2022-05-01 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [189/372] Rufe Daten ab für 2022-05-08 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [190/372] Rufe Daten ab für 2022-05-15 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [191/372] Rufe Daten ab für 2022-05-22 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [192/372] Rufe Daten ab für 2022-05-29 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [193/372] Rufe Daten ab für 2022-06-05 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [194/372] Rufe Daten ab für 2022-06-12 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [195/372] Rufe Daten ab für 2022-06-19 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [196/372] Rufe Daten ab für 2022-06-26 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [197/372] Rufe Daten ab für 2022-07-03 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [198/372] Rufe Daten ab für 2022-07-10 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [199/372] Rufe Daten ab für 2022-07-17 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [200/372] Rufe Daten ab für 2022-07-24 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [201/372] Rufe Daten ab für 2022-07-31 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [202/372] Rufe Daten ab für 2022-08-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [203/372] Rufe Daten ab für 2022-08-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [204/372] Rufe Daten ab für 2022-08-21 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [205/372] Rufe Daten ab für 2022-08-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [206/372] Rufe Daten ab für 2022-09-04 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [207/372] Rufe Daten ab für 2022-09-11 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [208/372] Rufe Daten ab für 2022-09-18 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [209/372] Rufe Daten ab für 2022-09-25 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [210/372] Rufe Daten ab für 2022-10-02 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [211/372] Rufe Daten ab für 2022-10-09 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [212/372] Rufe Daten ab für 2022-10-16 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [213/372] Rufe Daten ab für 2022-10-23 22:00:00
#   ✓ 676 Datenpunkte abgerufen
# [214/372] Rufe Daten ab für 2022-10-30 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [215/372] Rufe Daten ab für 2022-11-06 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [216/372] Rufe Daten ab für 2022-11-13 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [217/372] Rufe Daten ab für 2022-11-20 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [218/372] Rufe Daten ab für 2022-11-27 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [219/372] Rufe Daten ab für 2022-12-04 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [220/372] Rufe Daten ab für 2022-12-11 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [221/372] Rufe Daten ab für 2022-12-18 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [222/372] Rufe Daten ab für 2022-12-25 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [223/372] Rufe Daten ab für 2023-01-01 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [224/372] Rufe Daten ab für 2023-01-08 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [225/372] Rufe Daten ab für 2023-01-15 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [226/372] Rufe Daten ab für 2023-01-22 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [227/372] Rufe Daten ab für 2023-01-29 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [228/372] Rufe Daten ab für 2023-02-05 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [229/372] Rufe Daten ab für 2023-02-12 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [230/372] Rufe Daten ab für 2023-02-19 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [231/372] Rufe Daten ab für 2023-02-26 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [232/372] Rufe Daten ab für 2023-03-05 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [233/372] Rufe Daten ab für 2023-03-12 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [234/372] Rufe Daten ab für 2023-03-19 23:00:00
#   ✓ 668 Datenpunkte abgerufen
# [235/372] Rufe Daten ab für 2023-03-26 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [236/372] Rufe Daten ab für 2023-04-02 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [237/372] Rufe Daten ab für 2023-04-09 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [238/372] Rufe Daten ab für 2023-04-16 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [239/372] Rufe Daten ab für 2023-04-23 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [240/372] Rufe Daten ab für 2023-04-30 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [241/372] Rufe Daten ab für 2023-05-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [242/372] Rufe Daten ab für 2023-05-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [243/372] Rufe Daten ab für 2023-05-21 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [244/372] Rufe Daten ab für 2023-05-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [245/372] Rufe Daten ab für 2023-06-04 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [246/372] Rufe Daten ab für 2023-06-11 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [247/372] Rufe Daten ab für 2023-06-18 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [248/372] Rufe Daten ab für 2023-06-25 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [249/372] Rufe Daten ab für 2023-07-02 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [250/372] Rufe Daten ab für 2023-07-09 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [251/372] Rufe Daten ab für 2023-07-16 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [252/372] Rufe Daten ab für 2023-07-23 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [253/372] Rufe Daten ab für 2023-07-30 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [254/372] Rufe Daten ab für 2023-08-06 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [255/372] Rufe Daten ab für 2023-08-13 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [256/372] Rufe Daten ab für 2023-08-20 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [257/372] Rufe Daten ab für 2023-08-27 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [258/372] Rufe Daten ab für 2023-09-03 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [259/372] Rufe Daten ab für 2023-09-10 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [260/372] Rufe Daten ab für 2023-09-17 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [261/372] Rufe Daten ab für 2023-09-24 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [262/372] Rufe Daten ab für 2023-10-01 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [263/372] Rufe Daten ab für 2023-10-08 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [264/372] Rufe Daten ab für 2023-10-15 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [265/372] Rufe Daten ab für 2023-10-22 22:00:00
#   ✓ 676 Datenpunkte abgerufen
# [266/372] Rufe Daten ab für 2023-10-29 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [267/372] Rufe Daten ab für 2023-11-05 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [268/372] Rufe Daten ab für 2023-11-12 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [269/372] Rufe Daten ab für 2023-11-19 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [270/372] Rufe Daten ab für 2023-11-26 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [271/372] Rufe Daten ab für 2023-12-03 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [272/372] Rufe Daten ab für 2023-12-10 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [273/372] Rufe Daten ab für 2023-12-17 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [274/372] Rufe Daten ab für 2023-12-24 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [275/372] Rufe Daten ab für 2023-12-31 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [276/372] Rufe Daten ab für 2024-01-07 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [277/372] Rufe Daten ab für 2024-01-14 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [278/372] Rufe Daten ab für 2024-01-21 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [279/372] Rufe Daten ab für 2024-01-28 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [280/372] Rufe Daten ab für 2024-02-04 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [281/372] Rufe Daten ab für 2024-02-11 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [282/372] Rufe Daten ab für 2024-02-18 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [283/372] Rufe Daten ab für 2024-02-25 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [284/372] Rufe Daten ab für 2024-03-03 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [285/372] Rufe Daten ab für 2024-03-10 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [286/372] Rufe Daten ab für 2024-03-17 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [287/372] Rufe Daten ab für 2024-03-24 23:00:00
#   ✓ 668 Datenpunkte abgerufen
# [288/372] Rufe Daten ab für 2024-03-31 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [289/372] Rufe Daten ab für 2024-04-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [290/372] Rufe Daten ab für 2024-04-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [291/372] Rufe Daten ab für 2024-04-21 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [292/372] Rufe Daten ab für 2024-04-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [293/372] Rufe Daten ab für 2024-05-05 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [294/372] Rufe Daten ab für 2024-05-12 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [295/372] Rufe Daten ab für 2024-05-19 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [296/372] Rufe Daten ab für 2024-05-26 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [297/372] Rufe Daten ab für 2024-06-02 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [298/372] Rufe Daten ab für 2024-06-09 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [299/372] Rufe Daten ab für 2024-06-16 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [300/372] Rufe Daten ab für 2024-06-23 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [301/372] Rufe Daten ab für 2024-06-30 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [302/372] Rufe Daten ab für 2024-07-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [303/372] Rufe Daten ab für 2024-07-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [304/372] Rufe Daten ab für 2024-07-21 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [305/372] Rufe Daten ab für 2024-07-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [306/372] Rufe Daten ab für 2024-08-04 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [307/372] Rufe Daten ab für 2024-08-11 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [308/372] Rufe Daten ab für 2024-08-18 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [309/372] Rufe Daten ab für 2024-08-25 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [310/372] Rufe Daten ab für 2024-09-01 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [311/372] Rufe Daten ab für 2024-09-08 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [312/372] Rufe Daten ab für 2024-09-15 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [313/372] Rufe Daten ab für 2024-09-22 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [314/372] Rufe Daten ab für 2024-09-29 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [315/372] Rufe Daten ab für 2024-10-06 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [316/372] Rufe Daten ab für 2024-10-13 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [317/372] Rufe Daten ab für 2024-10-20 22:00:00
#   ✓ 676 Datenpunkte abgerufen
# [318/372] Rufe Daten ab für 2024-10-27 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [319/372] Rufe Daten ab für 2024-11-03 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [320/372] Rufe Daten ab für 2024-11-10 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [321/372] Rufe Daten ab für 2024-11-17 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [322/372] Rufe Daten ab für 2024-11-24 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [323/372] Rufe Daten ab für 2024-12-01 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [324/372] Rufe Daten ab für 2024-12-08 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [325/372] Rufe Daten ab für 2024-12-15 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [326/372] Rufe Daten ab für 2024-12-22 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [327/372] Rufe Daten ab für 2024-12-29 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [328/372] Rufe Daten ab für 2025-01-05 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [329/372] Rufe Daten ab für 2025-01-12 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [330/372] Rufe Daten ab für 2025-01-19 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [331/372] Rufe Daten ab für 2025-01-26 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [332/372] Rufe Daten ab für 2025-02-02 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [333/372] Rufe Daten ab für 2025-02-09 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [334/372] Rufe Daten ab für 2025-02-16 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [335/372] Rufe Daten ab für 2025-02-23 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [336/372] Rufe Daten ab für 2025-03-02 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [337/372] Rufe Daten ab für 2025-03-09 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [338/372] Rufe Daten ab für 2025-03-16 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [339/372] Rufe Daten ab für 2025-03-23 23:00:00
#   ✓ 668 Datenpunkte abgerufen
# [340/372] Rufe Daten ab für 2025-03-30 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [341/372] Rufe Daten ab für 2025-04-06 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [342/372] Rufe Daten ab für 2025-04-13 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [343/372] Rufe Daten ab für 2025-04-20 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [344/372] Rufe Daten ab für 2025-04-27 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [345/372] Rufe Daten ab für 2025-05-04 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [346/372] Rufe Daten ab für 2025-05-11 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [347/372] Rufe Daten ab für 2025-05-18 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [348/372] Rufe Daten ab für 2025-05-25 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [349/372] Rufe Daten ab für 2025-06-01 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [350/372] Rufe Daten ab für 2025-06-08 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [351/372] Rufe Daten ab für 2025-06-15 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [352/372] Rufe Daten ab für 2025-06-22 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [353/372] Rufe Daten ab für 2025-06-29 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [354/372] Rufe Daten ab für 2025-07-06 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [355/372] Rufe Daten ab für 2025-07-13 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [356/372] Rufe Daten ab für 2025-07-20 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [357/372] Rufe Daten ab für 2025-07-27 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [358/372] Rufe Daten ab für 2025-08-03 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [359/372] Rufe Daten ab für 2025-08-10 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [360/372] Rufe Daten ab für 2025-08-17 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [361/372] Rufe Daten ab für 2025-08-24 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [362/372] Rufe Daten ab für 2025-08-31 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [363/372] Rufe Daten ab für 2025-09-07 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [364/372] Rufe Daten ab für 2025-09-14 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [365/372] Rufe Daten ab für 2025-09-21 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [366/372] Rufe Daten ab für 2025-09-28 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [367/372] Rufe Daten ab für 2025-10-05 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [368/372] Rufe Daten ab für 2025-10-12 22:00:00
#   ✓ 672 Datenpunkte abgerufen
# [369/372] Rufe Daten ab für 2025-10-19 22:00:00
#   ✓ 676 Datenpunkte abgerufen
# [370/372] Rufe Daten ab für 2025-10-26 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [371/372] Rufe Daten ab für 2025-11-02 23:00:00
#   ✓ 672 Datenpunkte abgerufen
# [372/372] Rufe Daten ab für 2025-11-09 23:00:00
#   ✓ 672 Datenpunkte abgerufen
#
# ============================================================
# Datenabruf abgeschlossen!

# %%
# Zelle 6: Daten kombinieren und analysieren
if all_data:
    # Alle DataFrames kombinieren
    df_combined = pd.concat(all_data, ignore_index=True)
    
    # Nach Datum sortieren
    df_combined = df_combined.sort_values('datetime').reset_index(drop=True)
    
    # Duplikate entfernen (falls vorhanden)
    df_combined = df_combined.drop_duplicates(subset=['timestamp'])
    
    print(f"Gesamt: {len(df_combined)} Datenpunkte")
    print(f"Zeitraum: {df_combined['datetime'].min()} bis {df_combined['datetime'].max()}")
    print("\nErste 10 Einträge:")
    print(df_combined.head(10))
    
    # Statistiken
    print("\n" + "=" * 60)
    print("STATISTIKEN")
    print("=" * 60)
    print(f"Durchschnittspreis: {df_combined['value'].mean():.2f} EUR/MWh")
    print(f"Minimaler Preis:    {df_combined['value'].min():.2f} EUR/MWh")
    print(f"Maximaler Preis:    {df_combined['value'].max():.2f} EUR/MWh")
    print(f"Median:             {df_combined['value'].median():.2f} EUR/MWh")
else:
    print("Keine Daten verfügbar!")
# Out:
# Gesamt: 249988 Datenpunkte
# Zeitraum: 2018-09-30 22:00:00 bis 2025-11-16 22:45:00
#
# Erste 10 Einträge:
#        timestamp  value            datetime
# 0  1538344800000  59.53 2018-09-30 22:00:00
# 1  1538345700000  59.53 2018-09-30 22:15:00
# 2  1538346600000  59.53 2018-09-30 22:30:00
# 3  1538347500000  59.53 2018-09-30 22:45:00
# 4  1538348400000  56.10 2018-09-30 23:00:00
# 5  1538349300000  56.10 2018-09-30 23:15:00
# 6  1538350200000  56.10 2018-09-30 23:30:00
# 7  1538351100000  56.10 2018-09-30 23:45:00
# 8  1538352000000  51.41 2018-10-01 00:00:00
# 9  1538352900000  51.41 2018-10-01 00:15:00
#
# ============================================================
# STATISTIKEN
# ============================================================
# Durchschnittspreis: 93.17 EUR/MWh
# Minimaler Preis:    -500.00 EUR/MWh
# Maximaler Preis:    936.28 EUR/MWh
# Median:             70.00 EUR/MWh

# %%
# Zelle 7: Daten als CSV speichern
if all_data:
    filename = f"strompreise_deutschland_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    df_combined.to_csv(filename, index=False, encoding='utf-8-sig', sep=';')
    print(f"✓ Daten gespeichert in: {filename}")
    print(f"  Anzahl Zeilen: {len(df_combined)}")
    print(f"  Spalten: {', '.join(df_combined.columns)}")
# Out:
# ✓ Daten gespeichert in: strompreise_deutschland_20251112_074741.csv
#   Anzahl Zeilen: 249988
#   Spalten: timestamp, value, datetime

# %%
# Zelle 8: Optional - Visualisierung
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

if all_data:
    fig, ax = plt.subplots(figsize=(14, 6))
    
    ax.plot(df_combined['datetime'], df_combined['value'], linewidth=1.5)
    ax.set_xlabel('Datum', fontsize=12)
    ax.set_ylabel('Strompreis (EUR/MWh)', fontsize=12)
    ax.set_title('Strompreisentwicklung Deutschland (Day-Ahead Auktion)', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.3)
    
    # Datum-Formatierung auf der x-Achse
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d.%m.%Y'))
    plt.xticks(rotation=45)
    
    plt.tight_layout()
    plt.show()
    
    print("Visualisierung erstellt!")
# Out:
# Visualisierung erstellt!
